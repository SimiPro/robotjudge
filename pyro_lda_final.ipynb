# %%
#####################
#     LOAD DATA     #
#####################

import json_lines
import csv

def process_tweet(tweet):  
    d = {}
    d['hashtags'] = [hashtag['text'] for hashtag in tweet['entities']['hashtags']]
    d['text'] = tweet['full_text']
    d['user'] = tweet['user']['screen_name']
    d['user_loc'] = tweet['user']['location']
    d['created_at'] = tweet['created_at']
    return d

if False:
    with open('congress_dataset/senators-1.jsonl', 'rb') as f:
        with open(r'senators-1-tweets.csv', 'a') as file:
            writer = csv.writer(file)
            for item in json_lines.reader(f):
                # Only collect tweets in English
                if item['lang'] == 'en' and len(item['entities']['hashtags']) > 0:
                    tweet_data = process_tweet(item)
                    writer.writerow(list(tweet_data.values()))

                    
import pandas as pd
tweets = pd.read_csv("senators-1-tweets.csv", header=None, names=['hashtags', 'text', 'user', 'user_location', 'created_at'])  
print('num tweets: {}'.format(len(tweets)))


import spacy
nlp = spacy.load('en_core_web_md')

def tokenize(text):
    lda_tokens = []
    tokens = nlp(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens


import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma

from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)

nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))

def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4]
    tokens = [token for token in tokens if token not in en_stop]
    tokens = [get_lemma(token) for token in tokens]
    return tokens
    

import random

docs = []
hashtags = []
N = 2000
rand_tweets = list(range(N)) #random.sample(range(len(tweets)), k=N)
for i, tw in enumerate(rand_tweets):
    if i % 1000 == 0:
        print('{}%'.format(100./N*i), end=' ')
    text = tweets.iloc[i]['text']
    tokens = prepare_text_for_lda(text)
    if random.random() > .9999:
        print(tokens)
    taggs = tweets.iloc[i]['hashtags'].replace('[', '').replace(']', '').replace('\'', '').split(",")
    hashtags.append([t.strip() for t in taggs])
    docs.append(tokens)
# Out:
# num tweets: 449334
# [nltk_data] Downloading package wordnet to /home/simi/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/simi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0.0% 50.0% ['forward', 'hearing', 'tillerson', 'mattis', 'potus’', 'afghanistan', 'strategy', 'america', 'safe']

# %%
docs[0]
# Out:
# ['jones', 'greeting', 'crowd', 'SCREEN_NAME', 'rally', 'birmingham']

# %%
# here we should get only cleaned tweets
import gensim
from gensim.models import CoherenceModel, LdaModel, LsiModel, HdpModel
from gensim.models.wrappers import LdaMallet
from gensim.corpora import Dictionary

import torch
import numpy as np

N_SMALL = N

cleaned_tweetz = docs[:N_SMALL]

bigram = gensim.models.Phrases(cleaned_tweetz)
cleaned_tweetz = [bigram[t] for t in cleaned_tweetz]

# create dictionary and corpus
dictionary = Dictionary(cleaned_tweetz)

# corpus = (token_id, count_in_curr_doc) , sparse representation
corpus = [dictionary.doc2bow(clean_tween) for clean_tween in cleaned_tweetz]
cleaned_tweetz_id = [dictionary.doc2idx(document=tw) for tw in cleaned_tweetz]

# Cut all tweets after 5 words and remove tweets below 5 words
cleaned_tweetz_id = [tw for tw in cleaned_tweetz_id if len(tw) >= 5]
cleaned_tweetz_id = [tw[:5] for tw in cleaned_tweetz_id]
cleaned_tweetz_id = torch.Tensor(np.array([np.array(tw, dtype=np.int32) for tw in cleaned_tweetz_id])).long()
cleaned_tweetz_id = cleaned_tweetz_id.transpose(1,0)

# %%
# Out:
# [['jones', 'greeting', 'crowd', 'SCREEN_NAME', 'rally_birmingham'],
#  ['suppose',
#   'things',
#   'better',
#   'behind',
#   'generational',
#   'responsibility',
#   'chance',
#   'right',
#   'direction',
#   'jones',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'rally_birmingham'],
#  ['thank',
#   'SCREEN_NAME',
#   'endorsement',
#   'amaze',
#   'night',
#   'december',
#   'gotv4doug'],
#  ['thank',
#   'great',
#   'alabamian',
#   'cooley',
#   'SCREEN_NAME',
#   'support',
#   'endorsement',
#   'votedec12',
#   'gotv4doug'],
#  ['backstage',
#   'louise',
#   'final_gotv4doug',
#   'rally',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'charlesbarkley',
#   'rightsideofhistory'],
#  ['somebody',
#   'election',
#   'movie',
#   'script',
#   'would',
#   'throw',
#   'trash',
#   'would',
#   'possible',
#   'leading',
#   'polls',
#   'charlesbarkley',
#   'final_gotv4doug',
#   'rally'],
#  ['begging',
#   'friend',
#   'point',
#   'charlesbarkley',
#   'gotv4doug',
#   'final',
#   'rally'],
#  ['mayor',
#   'birmingham',
#   'SCREEN_NAME',
#   'senator',
#   'alabama-',
#   'jones',
#   'gotv4doug',
#   'final',
#   'rally',
#   'charlesbarkley'],
#  ['climb',
#   'uphill',
#   'battle',
#   'people',
#   'world',
#   'first',
#   'going',
#   'SCREEN_NAME',
#   'gotv4doug',
#   'final',
#   'rally'],
#  ['jones',
#   'winning',
#   'getting',
#   'inch',
#   'birmingham',
#   'first',
#   'december',
#   'jones_final',
#   'gotv4doug_rally'],
#  ['tomorrow', 'jones_final', 'gotv4doug_rally'],
#  ['significant',
#   'election',
#   'state',
#   'progress',
#   'jones_final',
#   'gotv4doug_rally'],
#  ['state',
#   'decency',
#   'political',
#   'party',
#   'discriminate',
#   'least',
#   'fortunate',
#   'among',
#   'moore',
#   'jones_final',
#   'gotv4doug_rally'],
#  ['rightsideofhistory',
#   'folks',
#   'courageous',
#   'woman',
#   'jones_final',
#   'gotv4doug_rally'],
#  ['history',
#   'grave',
#   'lifetime',
#   'form',
#   'tidal',
#   'justice',
#   'jones_final',
#   'gotv4doug_rally'],
#  ['shaking', 'hands', 'meeting', 'possible', 'final_gotv4doug', 'rally'],
#  ['SCREEN_NAME',
#   'alabamian',
#   'please',
#   'tuesday',
#   'special',
#   'senate',
#   'election',
#   'dougjones',
#   'watch',
#   'share'],
#  ['SCREEN_NAME',
#   'alabama',
#   'today',
#   'talking',
#   'incredible',
#   'working',
#   'people',
#   'behind',
#   'dougjonesforsenate',
#   'campaign'],
#  ['SCREEN_NAME',
#   'SCREEN_NAME',
#   'goblazers',
#   'gotv4doug',
#   'rightsideofhistory'],
#  ['today', 'rightsideofhistory'],
#  ['SCREEN_NAME', 'wonder', 'alpolitics', 'alsen'],
#  ['student',
#   'alabama',
#   'native',
#   'SCREEN_NAME',
#   'special',
#   'message',
#   'still',
#   'details',
#   'rightsideofhistory'],
#  ['SCREEN_NAME', 'driving', 'people', 'polls', 'gotv4doug'],
#  ['people',
#   'alabama',
#   'speak',
#   'never',
#   'never',
#   'moore',
#   'jones',
#   'election',
#   'night',
#   'victory',
#   'rightsideofhistory'],
#  ['entire',
#   'dignity',
#   'respect',
#   'campaign',
#   'campaign',
#   'common',
#   'courtesy',
#   'decency',
#   'making',
#   'everyone',
#   'state',
#   'shake',
#   'jones',
#   'election',
#   'night',
#   'victory',
#   'rightsideofhistory'],
#  ['washington',
#   'election',
#   'great',
#   'state',
#   'alabama',
#   'opportunity',
#   'common',
#   'ground',
#   'ahead',
#   'program',
#   'jones',
#   'election',
#   'night',
#   'victory',
#   'rightsideofhistory'],
#  ['personal',
#   'level',
#   'thank',
#   'fulfil',
#   'lifelong',
#   'dream',
#   'serve',
#   'senate',
#   'state',
#   'thank',
#   'bless',
#   'jones',
#   'election',
#   'night',
#   'victory',
#   'rightsideofhistory'],
#  ['watch',
#   'tapper',
#   'SCREEN_NAME',
#   'discuss',
#   'campaign',
#   'victory',
#   'plan',
#   'common',
#   'ground',
#   'senate',
#   'tunein'],
#  ['join',
#   'chris',
#   'wallace',
#   'sunday',
#   'discus',
#   'plan',
#   'across',
#   'aisle',
#   'alabama',
#   'america',
#   'strong',
#   'tunein'],
#  ['senate', 'concern', 'would', 'trillion', 'national'],
#  ['consequential', 'election', 'impact', 'everyone', 'thing', 'oneweek'],
#  ['moore',
#   'medium',
#   'voter',
#   'campaign',
#   'debate',
#   'could',
#   'handle',
#   'calling',
#   'embarrassing-',
#   'think',
#   'senate',
#   'disturb',
#   'history',
#   'nomoore'],
#  ['parent',
#   'grandparent',
#   'jade',
#   'politics',
#   'decency',
#   'political',
#   'party',
#   'anyone',
#   'think',
#   'otherwise',
#   'ashamed',
#   'oneweek'],
#  ['thanks', 'others', 'donate', 'oneweek', 'rightsideofhistory'],
#  ['crystal',
#   'clear',
#   'woman',
#   'telling',
#   'truth',
#   'moore',
#   'oneweek',
#   'rightsideofhistory'],
#  ['believe', 'woman', 'oneweek', 'rightsideofhistory'],
#  ['daughter',
#   'abuse',
#   'speak',
#   'believe',
#   'alabama',
#   'stand',
#   'regardless',
#   'forward',
#   'oneweek',
#   'rightsideofhistory'],
#  ['funding',
#   'help',
#   '150,000',
#   'alabama',
#   'access',
#   'healthcare',
#   'could',
#   'otherwise',
#   'afford',
#   'kitchentableissues'],
#  ['responsibility',
#   'obligation',
#   'people',
#   'drive',
#   'serving',
#   'political',
#   'interest',
#   'rightsideofhistory'],
#  ['SCREEN_NAME',
#   'photo',
#   'gallery',
#   'jones',
#   'visit',
#   'huntsville',
#   'campaign',
#   'center',
#   'SCREEN_NAME',
#   'alpolitics'],
#  ['SCREEN_NAME',
#   'valid',
#   'senate',
#   'special',
#   'election',
#   'alabama',
#   'tuesday',
#   'alsen_alpolitics'],
#  ['take', 'stage', 'SCREEN_NAME', 'rally_birmingham', 'hero', 'welcome'],
#  ['going',
#   'people',
#   'thanks',
#   'phone',
#   'cross',
#   'million',
#   'phone',
#   'call',
#   'thanks',
#   'commitment',
#   'jones',
#   'SCREEN_NAME',
#   'rally_birmingham'],
#  ['sound',
#   'break',
#   'record',
#   'going',
#   'finish',
#   'campaign',
#   'start',
#   'talking',
#   'kitchen',
#   'table',
#   'issue',
#   'healthcare',
#   'education',
#   'jones',
#   'SCREEN_NAME',
#   'rally_birmingham'],
#  ['party',
#   'belong',
#   'first',
#   'question',
#   'ask',
#   'office',
#   'purpose',
#   'party',
#   'belong',
#   'jones',
#   'SCREEN_NAME',
#   'rally_birmingham'],
#  ['moore',
#   'disaster',
#   'state',
#   'point',
#   'represent',
#   'every',
#   'woman',
#   'child',
#   'select',
#   'jones',
#   'SCREEN_NAME',
#   'rally_birmingham'],
#  ['question',
#   'election',
#   'question',
#   'alabama',
#   'moore',
#   'divisiveness',
#   'jones',
#   'SCREEN_NAME',
#   'rally_birmingham'],
#  ['opportunity',
#   'december',
#   'history',
#   'rhyme-',
#   'history',
#   'thank',
#   'jones',
#   'closing',
#   'SCREEN_NAME',
#   'rally_birmingham'],
#  ['kitchentableissues',
#   'people',
#   'everyday',
#   'healthcare',
#   'education',
#   'history',
#   'right_thing',
#   'final',
#   'shock',
#   'world',
#   'december'],
#  ['thank',
#   'everyone',
#   'support',
#   'fighting',
#   'kitchentableissues',
#   'campaign',
#   'alabamian',
#   'issue',
#   'everyday',
#   'rightsideofhistory',
#   'bottom',
#   'heart-',
#   'thank',
#   'standing'],
#  ['republican', 'jones', 'gop4jones', 'alsen'],
#  ['powerful',
#   'endorsement',
#   'steve',
#   'duncan',
#   'thank',
#   'steve',
#   'alsen',
#   'rightsideofhistory'],
#  ['campaign',
#   'gain',
#   'momentum',
#   'supporter',
#   'every',
#   'corner',
#   'alabama',
#   'prepare',
#   'final',
#   'voting',
#   'december',
#   'count',
#   'alsen'],
#  ['support',
#   'kitchentableissues',
#   'rightsideofhistory',
#   'challenge',
#   'record',
#   'selfie',
#   'saying',
#   'support',
#   'challenge',
#   'friend',
#   'website',
#   'everyone',
#   'stand'],
#  ['unify',
#   'campaign',
#   'getting',
#   'endorsement',
#   'crimson',
#   'white',
#   'plainsman',
#   'awesome',
#   'proof',
#   'alcometogether',
#   'rolltide',
#   'wareagle'],
#  ['house',
#   'restaurant',
#   'dothan',
#   'amaze',
#   'energize',
#   'group',
#   'ready',
#   'kitchentableissues'],
#  ['alabama-',
#   'campaign',
#   'gain',
#   'momentum',
#   'alabama',
#   'want',
#   'kitchentableissues',
#   'impact',
#   'life',
#   'prepare',
#   'election',
#   'voting',
#   'december',
#   'verify',
#   'alsen'],
#  ['walk',
#   'square',
#   'meeting',
#   'people',
#   'enjoy',
#   'milkshake',
#   'company',
#   'alsen'],
#  ['honor',
#   'endorsement',
#   'birmingham',
#   'huntsville',
#   'times',
#   'mobile',
#   'press',
#   'register',
#   'talking',
#   'issue',
#   'impact',
#   'life',
#   'finding',
#   'common',
#   'ground',
#   'things',
#   'better',
#   'alabama',
#   'kitchentableissues'],
#  ['thanks', 'gop4jones'],
#  ['SCREEN_NAME',
#   'SCREEN_NAME',
#   'pretty',
#   'happy',
#   'campaign',
#   'bringing',
#   'people',
#   'together',
#   'talking',
#   'kitchentableissues',
#   'support',
#   'matter'],
#  ['though',
#   'opponent',
#   'join',
#   'madison',
#   'county',
#   'kitchentableissues',
#   'matter'],
#  ['public',
#   'service',
#   'force',
#   'jones-',
#   'madison',
#   'county',
#   'kitchentableissues'],
#  ['change', 'stripes', 'jones-', 'madison', 'county', 'rightsideofhistory'],
#  ['amaze', 'meeting', 'great', 'people', 'ironbowlِ'],
#  ['speaking', 'hundred', 'people', 'greensboro', 'county', 'banquet', 'alsen'],
#  ['alabama',
#   'beyond',
#   'moore',
#   'order',
#   'forward',
#   'state',
#   'country',
#   'party',
#   'jones-',
#   'greensboro',
#   'county',
#   'banquet',
#   'alsen'],
#  ['alabamian',
#   'common',
#   'difference',
#   'serving',
#   'politician',
#   'moore',
#   'divide',
#   'jones-',
#   'greensboro',
#   'county',
#   'banquet',
#   'alsen'],
#  ['several',
#   'rural',
#   'hospital',
#   'leaders',
#   'politics',
#   'health',
#   'going',
#   'health',
#   'bringing',
#   'costs',
#   'expand',
#   'access',
#   'coverage',
#   'jones-',
#   'greensboro',
#   'county',
#   'banquet',
#   'alsen'],
#  ['education', 'change', 'child', 'alsen', 'kitchentableissues'],
#  ['strongly',
#   'support',
#   'netneutrality',
#   'believe',
#   'every',
#   'alabamian',
#   'access_internet'],
#  ['join',
#   'SCREEN_NAME',
#   'campaign',
#   'bring',
#   'alabamian',
#   'together',
#   'talking',
#   'issue',
#   'affect'],
#  ['speaking',
#   'daphne',
#   'macedonia',
#   'missionary',
#   'baptist',
#   'church',
#   'powerful',
#   'moment',
#   'rightsideofhistory'],
#  ['reason', 'embarrassment', 'focus', 'kitchentableissues', 'people'],
#  ['louise',
#   'classic',
#   'affair',
#   'friend',
#   'birmingham',
#   'mayor',
#   'SCREEN_NAME',
#   'magiccityclassic'],
#  ['attending', 'magiccityclassic2017', 'louise', 'friend', 'SCREEN_NAME'],
#  ['.@repterrisewell',
#   'join',
#   'president',
#   'alabama',
#   'state',
#   'university',
#   'alabama',
#   'a&amp;m',
#   'field',
#   'magiccityclassic2017'],
#  ['SCREEN_NAME',
#   'undermine',
#   'medicare',
#   'medicaid',
#   'refuse',
#   'commit',
#   'funding',
#   'alabama'],
#  ['SCREEN_NAME', 'leave', 'swamp', 'alabamian', 'kitchentableissues', 'alsen'],
#  ['important'],
#  ['tailgate', 'tuscaloosa', 'rolltide', 'beatlsu'],
#  ['praise',
#   'montgomery',
#   'bishop',
#   'clarence',
#   'stewart',
#   'talking',
#   'alsen',
#   'attorney',
#   'health'],
#  ['thank',
#   'proud',
#   'endorsement',
#   'great',
#   'folks',
#   'crimson',
#   'white',
#   'university',
#   'alabama',
#   'rolltide'],
#  ['moore',
#   'afraid',
#   'debate',
#   'support',
#   'health',
#   'support',
#   'health',
#   'almost',
#   'senior',
#   'answer_question',
#   'charity',
#   'extreme',
#   'view',
#   'business',
#   'alsen'],
#  ['mobile',
#   'veteran',
#   'parade',
#   'cannonball',
#   'landry',
#   'join',
#   'marine',
#   'corps',
#   'pipefitter',
#   'since',
#   'happy',
#   '242nd',
#   'birthday',
#   'marine',
#   'corps',
#   'happybirthdaymarines'],
#  ['excite',
#   'friend',
#   'SCREEN_NAME',
#   'mobile',
#   'kitchentableissues',
#   'tonight'],
#  ['first',
#   'harvey',
#   'remember',
#   'friend',
#   'prepare',
#   'worst',
#   'alsen_alpolitics'],
#  ['divide',
#   'build',
#   'bridges',
#   'wall',
#   'justice',
#   'division',
#   'start',
#   'south',
#   'healing',
#   'weremember'],
#  ['honor',
#   'friend',
#   'SCREEN_NAME',
#   'campaign',
#   "b'ham",
#   'alsen_alpolitics',
#   'dougjonesforsenate'],
#  ['great',
#   'voting',
#   'right',
#   'panel',
#   'terri',
#   'sewell',
#   'cbcalc2017',
#   "nat'l",
#   'voter',
#   'restorethevote'],
#  ['proud',
#   'anthony',
#   'daniel',
#   'accept',
#   'champion',
#   'woman',
#   'health',
#   'plan',
#   'parenthood',
#   'wepersist'],
#  ['focus',
#   'unity',
#   'sport',
#   'rather',
#   'division',
#   'support',
#   'wounded',
#   'warrior',
#   'compete',
#   'invictusgames2017'],
#  ['crystal',
#   'clear',
#   'support',
#   'right',
#   'protest',
#   'freedom',
#   'expression',
#   'takeaknee',
#   'focus',
#   'inequality',
#   'injustice'],
#  ['today',
#   'nationalvoterregistrationday',
#   'hands',
#   'register',
#   'ready',
#   '12/12'],
#  ['bamavsolemiss', 'awesome', 'people'],
#  ['great', 'friend', 'diego', 'bamavsolemiss'],
#  ['crowd', 'waiting', 'rally', 'start', 'bidenjoneslive', '-djfs'],
#  ['SCREEN_NAME',
#   'biden',
#   'know',
#   'alabama',
#   'know',
#   'heart',
#   'never',
#   'alpolitics',
#   'alsen'],
#  ['bidenjoneslive', 'today'],
#  ['nearly', 'child', 'living', 'poverty', 'literally', 'kitchentableissues'],
#  ['thought', 'coast', 'hurricanenate', 'make', 'landfall', 'careful'],
#  ['choice',
#   'voter',
#   'december',
#   'define',
#   'generation',
#   'therightsideofhistory'],
#  ['another', 'crook', 'career', 'politician', 'mooreforhimself'],
#  ['visit',
#   'courtland',
#   'spoke',
#   'impact',
#   'closure',
#   'paper',
#   'story',
#   'kitchentableissues',
#   'alsenate'],
#  ['prayer',
#   'victim',
#   'family',
#   'charleston',
#   'understand',
#   'heartache',
#   'innocent',
#   'life',
#   'house',
#   'wearechalreston'],
#  ['birmingham',
#   'understand',
#   'heartache',
#   'innocent',
#   'life',
#   'house',
#   'prayer',
#   'victim',
#   'family',
#   'charlestonshooting'],
#  ['recent',
#   'interview',
#   'tragic',
#   'event',
#   'charleston',
#   'charlestonshooting',
#   'audio'],
#  ['comparison',
#   'SCREEN_NAME',
#   'birmingham',
#   'church',
#   'bombing',
#   'terrible',
#   'shooting',
#   'charleston',
#   'charlestonshooting'],
#  ['alabama',
#   'great',
#   'public',
#   'servant',
#   'today',
#   'passing',
#   'etowah',
#   'county',
#   'jimmie',
#   'friend',
#   'colleague',
#   'ripjimmie'],
#  ['proud',
#   'another',
#   'endorsement',
#   'dougjones4senate',
#   'jones',
#   'brooks',
#   'senate',
#   'editorial'],
#  ['luther',
#   'strange',
#   'president_trump',
#   'support',
#   'family',
#   'support',
#   'child',
#   'alpolitics',
#   'alsen'],
#  ['luther',
#   'strange',
#   'president_trump',
#   'support',
#   'family',
#   'child',
#   'alpolitics',
#   'alsen'],
#  ['happy',
#   'old',
#   'labor',
#   'celebration',
#   'country',
#   'shoal',
#   'labor',
#   'council',
#   'alsen_alpolitics'],
#  ['moore', 'mcconnell', 'teaching', 'russian', 'luther', 'alsen_alpolitics'],
#  ['mcconnell',
#   'senate',
#   'leadership',
#   'sinking',
#   'million',
#   'luther',
#   'question',
#   'ask',
#   'alsen_alpolitics'],
#  ['statement',
#   'today',
#   'action',
#   'luther',
#   'strange',
#   'steps',
#   'right_thing',
#   'alsen_alpolitics'],
#  ['SCREEN_NAME',
#   '.@lindseygrahamsc',
#   'join',
#   'thebriankilmeadeshow',
#   'discus',
#   'attempt',
#   'suicide',
#   'bombing',
#   'manhattan',
#   'SCREEN_NAME',
#   'SCREEN_NAME'],
#  ['peacekeeper',
#   'ultimate',
#   'sacrifice',
#   'democratic',
#   'republic',
#   'congo',
#   'service',
#   'bright',
#   'future',
#   'deadly',
#   'attack',
#   'peacekeeper',
#   'decade'],
#  ['people',
#   'enroll',
#   'health',
#   'qualify',
#   'financial',
#   'getcovered',
#   'deadline',
#   'december'],
#  ['immigrant',
#   'jersey',
#   'employ',
#   '270,431',
#   'people',
#   'imarch',
#   'creator',
#   'million',
#   'immigrant',
#   'building',
#   'country',
#   'every'],
#  ['SCREEN_NAME',
#   '.@chrislhayes',
#   'SCREEN_NAME',
#   'prepare',
#   'moore',
#   'colleague',
#   'inners'],
#  ['SCREEN_NAME', 'SCREEN_NAME', 'SCREEN_NAME'],
#  ['SCREEN_NAME',
#   'letter',
#   'senator',
#   'SCREEN_NAME',
#   'urge',
#   'federal',
#   'official',
#   'rebuild',
#   'worker',
#   'power',
#   'warn',
#   'growing',
#   'monopsony'],
#  ['people',
#   'enroll',
#   'health',
#   'qualify',
#   'financial',
#   'getcovered',
#   'deadline',
#   'friday',
#   'december'],
#  ['health_coverage', 'tomorrow', 'deadline_getcovered'],
#  ['SCREEN_NAME', 'internet', 'already', 'internet', 'netneutrality'],
#  ['health',
#   'tomorrow',
#   'deadline',
#   'people',
#   'enroll',
#   'plan',
#   'month',
#   'getcovered',
#   'tomorrow',
#   'deadline'],
#  ['direct',
#   'nothing',
#   'change',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'military',
#   'option',
#   'running',
#   'northkorea'],
#  ['deadline_getcovered', 'today', 'quality', 'affordable', 'health'],
#  ['SCREEN_NAME', 'spread', 'today', 'getcovered', 'enrollyoself'],
#  ['climatechange',
#   'cause',
#   'displacement',
#   'across',
#   'africa',
#   'force',
#   'people',
#   'home',
#   'drought',
#   'flooding',
#   'natural',
#   'disaster',
#   'million',
#   'african',
#   'impact',
#   'water',
#   'stress',
#   'alone'],
#  ['noise',
#   'powerful',
#   'sound',
#   'marching',
#   'determine',
#   'people',
#   'mondaymotivation'],
#  ['happy_birthday',
#   'great',
#   'state',
#   'jersey',
#   'join',
#   'union',
#   'years',
#   'today',
#   'jerseyproud'],
#  ['morning',
#   'attack',
#   'senator',
#   'hatch',
#   'spoke',
#   'senate_floor',
#   'purpose',
#   'direction',
#   'american',
#   'foreign',
#   'policy',
#   'utpol'],
#  ['family',
#   'riverton',
#   'getting',
#   'venezuelan',
#   'prison',
#   'calling',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'fight',
#   'bring',
#   'utpol'],
#  ['ample',
#   'experience',
#   'legislator',
#   'doctor',
#   'senator',
#   'brian',
#   'shiozawa',
#   'uniquely',
#   'qualify',
#   'navigate',
#   'multifaceted',
#   'healthcare',
#   'market',
#   'doubt',
#   'prime',
#   'addition',
#   'photo',
#   'hatch',
#   'shiozawa',
#   'earlier',
#   'today',
#   'utpol'],
#  ['happyhanukkah', 'friend', 'celebrate', 'around_world', 'sameach'],
#  ['moral', 'universe', 'bends', 'toward', 'justice', 'wednesdaywisdom'],
#  ['moment',
#   'SCREEN_NAME',
#   'chairman',
#   'hatch',
#   'president',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'chairman',
#   'SCREEN_NAME',
#   'discuss',
#   'major',
#   'development',
#   'taxreform',
#   'utpol'],
#  ['debate',
#   'break',
#   'system',
#   'important',
#   'separate',
#   'fiction',
#   'amount',
#   'seeing',
#   'social',
#   'medium',
#   'simply',
#   'wrong',
#   'taxreform'],
#  ['judge',
#   'effort',
#   'please',
#   'consider',
#   'source',
#   'believe',
#   'everything',
#   'proof',
#   'paycheck',
#   'taxreform'],
#  ['fight',
#   'netneutrality',
#   'protect',
#   'competitive',
#   'online',
#   'marketplace',
#   'great',
#   'anyone',
#   'anywhere'],
#  ['SCREEN_NAME',
#   'morning',
#   'SCREEN_NAME',
#   'taxreform',
#   'boost',
#   'technology',
#   'productivity'],
#  ['egregious',
#   'attack',
#   'democracy',
#   'netneutrality_protection',
#   'means',
#   'internet',
#   'high',
#   'bidder',
#   'democratic',
#   'institution',
#   'already',
#   'peril',
#   'everything',
#   'decision',
#   'taking',
#   'effect'],
#  ['SCREEN_NAME',
#   'meeting',
#   'SCREEN_NAME',
#   'discus',
#   'usapoverty',
#   'finding',
#   'mission',
#   'speci'],
#  ['SCREEN_NAME',
#   'repeal_netneutrality',
#   'rule',
#   'party',
#   'hand',
#   'multi',
#   'billion',
#   'dollar',
#   'broadband',
#   'company'],
#  ['vote',
#   'repeal_netneutrality',
#   'everything',
#   'egregious',
#   'decision',
#   'taking',
#   'effect'],
#  ['internet', 'congress', 'court', 'fight', 'netneutrality'],
#  ['hatch',
#   'joining',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'discus',
#   'taxreform',
#   'situation',
#   'venezuela',
#   'utpol'],
#  ['SCREEN_NAME',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'found',
#   'trial',
#   'venezuela',
#   'deny',
#   'medical',
#   'prison',
#   'hatch',
#   'ask',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'bringing',
#   'family',
#   'utpol',
#   'justiceforjosh'],
#  ['SCREEN_NAME',
#   'thank',
#   'senator',
#   'orrin',
#   'hatch',
#   'joining',
#   'tonight',
#   'specialreport'],
#  ['SCREEN_NAME',
#   'today',
#   'deadline_getcovered',
#   'affordable',
#   'health_coverage',
#   'right'],
#  ['icymi',
#   'night',
#   'hatch',
#   'SCREEN_NAME',
#   'effort',
#   'bring',
#   'venezuela',
#   'captive',
#   'nearly',
#   'month',
#   'justiceforjosh',
#   'utpol'],
#  ['girl', 'breakfast', 'girlsbuildla'],
#  ['SCREEN_NAME',
#   'chairman',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'release',
#   'taxreform',
#   'conference_committee',
#   'report'],
#  ['SCREEN_NAME',
#   'statement',
#   'taxcutsandjobsact',
#   'conference_report',
#   'release',
#   'today',
#   'bring',
#   'taxreform'],
#  ['hatch',
#   'today',
#   'marks',
#   'critical',
#   'milestone',
#   'endeavor',
#   'keep',
#   'track',
#   'deliver',
#   'comprehensive',
#   'overhaul',
#   'american_people',
#   'utpol'],
#  ['going', 'change', 'major', 'reduction', 'tax', 'taxreform', 'utpol'],
#  ['SCREEN_NAME',
#   'icymi',
#   'chairman',
#   'SCREEN_NAME',
#   'join',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'discus',
#   'historic',
#   'taxreform',
#   'effort'],
#  ['people',
#   'SCREEN_NAME',
#   'fight',
#   'goptaxscam',
#   'defeat',
#   'horrific',
#   'piece',
#   'legislation',
#   'everyone',
#   'stand',
#   'fight'],
#  ['broadband',
#   'essential',
#   'compete',
#   'global',
#   'digital',
#   'economy',
#   'SCREEN_NAME',
#   'explain',
#   'include',
#   'working',
#   'bridge',
#   'digitaldivide'],
#  ['introduce',
#   'legislation',
#   'authorize',
#   'SCREEN_NAME',
#   'alzheimer',
#   'stamp',
#   'revenue',
#   'support',
#   'SCREEN_NAME',
#   'research',
#   'effort'],
#  ['connect',
#   'virginia',
#   'require',
#   'hands',
#   'approach',
#   'capitoconnect',
#   'helping',
#   'right',
#   'steps',
#   'tackle',
#   'problem',
#   'SCREEN_NAME'],
#  ['SCREEN_NAME',
#   'sign',
#   'bipartisan',
#   'troops',
#   'large',
#   'increase',
#   'eight',
#   'years'],
#  ['cybersecurity',
#   'industry',
#   'leaders',
#   'support',
#   'mgtact',
#   'please',
#   'SCREEN_NAME',
#   'sign',
#   'vital',
#   'bipartisan',
#   'legislation',
#   'bring',
#   'federal',
#   'system',
#   'century'],
#  ['.@wvachamber', 'agree', 'taxreform', 'component', 'strong', 'economy'],
#  ['mgtact',
#   'SCREEN_NAME',
#   'taxpayer',
#   'billion',
#   'modernize',
#   'outdated',
#   'federal',
#   'system',
#   'strengthening',
#   'government',
#   'cybersecurity'],
#  ['happy_hanukkah', 'virginian', 'celebrate'],
#  ['SCREEN_NAME',
#   'happy_hanukkah',
#   'sameach',
#   'celebrate',
#   'america',
#   'israel',
#   'around_world'],
#  ['direct', 'resource', 'critical', 'tackle', 'opioidepidemic', 'SCREEN_NAME'],
#  ['thousand',
#   'child',
#   'family',
#   'urging',
#   'colleague',
#   'extendchip',
#   'important',
#   'program'],
#  ['SCREEN_NAME',
#   'happy',
#   '381st_birthday',
#   'SCREEN_NAME',
#   'alwaysreadyalwaysthere',
#   'since',
#   'guard381',
#   'learn'],
#  ['taxreform',
#   'means',
#   'investment',
#   'SCREEN_NAME',
#   'support',
#   'overdue',
#   'reform'],
#  ['taxreform', 'change', 'economy', 'growing', 'SCREEN_NAME', 'agree'],
#  ['thank',
#   'SCREEN_NAME',
#   'supporting',
#   'military',
#   'signing',
#   'yesterday',
#   'important',
#   'funds',
#   'military',
#   'national',
#   'security',
#   'priority',
#   'give',
#   'troops',
#   'raise',
#   'support',
#   'service',
#   'family'],
#  ['really',
#   'think',
#   'verizon',
#   'comcast',
#   'at&amp;t',
#   'warner',
#   'money',
#   'repeal_netneutrality',
#   'SCREEN_NAME'],
#  ['taxreform',
#   'generation',
#   'opportunity',
#   'provide',
#   'need',
#   'relief',
#   'virginian',
#   'every',
#   'income',
#   'category',
#   'SCREEN_NAME',
#   'urging',
#   'congress',
#   'support',
#   'reform'],
#  ['SCREEN_NAME',
#   'affect',
#   'destruction',
#   'internet',
#   'laugh',
#   'netneutrality'],
#  ['SCREEN_NAME',
#   'talkline',
#   'around',
#   '10:30',
#   'morning',
#   'talking',
#   'agreement',
#   'reach',
#   'taxreform',
#   'listen'],
#  ['ahead',
#   'netneutrality',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'stand',
#   'american_people',
#   'protect',
#   'internet'],
#  ['moment',
#   'democratic',
#   'institution',
#   'peril',
#   'ending',
#   'netneutrality_protection',
#   'would',
#   'devastate',
#   'ending',
#   'internet'],
#  ['since',
#   'SCREEN_NAME',
#   'diagnose',
#   '370,000',
#   'servicemembers',
#   'traumatic',
#   'brain',
#   'injury',
#   'diagnose',
#   'deployment',
#   'setting',
#   'subcommittee',
#   'personnel',
#   'hear',
#   'testimony',
#   'update',
#   'research',
#   'diagnosis',
#   'treatment',
#   'concussion',
#   'servicemembers'],
#  ['SCREEN_NAME', 'tomorrow', 'chance', 'getcovered', 'waste', 'today'],
#  ['SCREEN_NAME',
#   'talking',
#   'taxreform',
#   'small_business',
#   'owner',
#   'manufacturer',
#   'family',
#   'individual',
#   'across',
#   'support',
#   'watch'],
#  ['taxreform',
#   'nearly',
#   'double',
#   'standard',
#   'deduction',
#   'already',
#   'virginian'],
#  ['taxreform',
#   'increase',
#   'childtaxcredit',
#   'family',
#   'american',
#   'business',
#   'competitive',
#   'globally',
#   'higher_wages',
#   'opportunity',
#   'worker'],
#  ['today',
#   'closer',
#   'getting',
#   'comprehensive',
#   'growth',
#   'taxreform',
#   'across',
#   'finish',
#   'virginian',
#   'rooting',
#   'effort',
#   'positive',
#   'difference',
#   'life'],
#  ['virginian', 'taxreform', 'state'],
#  ['.@nfib_wv',
#   'taxreform',
#   'provide',
#   'need',
#   'relief',
#   'business',
#   'compete'],
#  ['.@wvachamber', 'support', 'taxreform', 'call'],
#  ['.@afpwv', 'support', 'taxreform', 'business', 'competitive'],
#  ['SCREEN_NAME', 'express', 'support', 'taxreform', 'create', 'investment'],
#  ['seize',
#   'important',
#   'generation',
#   'opportunity',
#   'taxreform',
#   'across',
#   'finish',
#   'growth',
#   'legislation',
#   'SCREEN_NAME'],
#  ['family',
#   'worker',
#   'small_business',
#   'virginia',
#   'across_country',
#   'counting',
#   'congress',
#   'taxreform'],
#  ['internet',
#   'essential',
#   'consumer',
#   'innovator',
#   'economy',
#   'whole',
#   'republican',
#   'SCREEN_NAME',
#   'repeal_netneutrality',
#   'hurt',
#   'american_people',
#   'economy',
#   'speaking',
#   'fighting',
#   'internet'],
#  ['SCREEN_NAME',
#   'fight',
#   'joining',
#   'SCREEN_NAME',
#   'legislation',
#   'overturn',
#   'today',
#   'backward',
#   'decision',
#   'netneutrality'],
#  ['piece',
#   'SCREEN_NAME',
#   'importance',
#   'immigrant',
#   'entrepreneur',
#   'bipartisan',
#   'startupact',
#   'mention',
#   'would',
#   'certain',
#   'america',
#   'remains',
#   'opportunity',
#   'innovator',
#   'creator',
#   'around_world'],
#  ['tomorrow', 'getcovered'],
#  ['SCREEN_NAME',
#   'thank',
#   'SCREEN_NAME',
#   'commitment',
#   'reaching',
#   'across',
#   'aisle',
#   'solution',
#   'dreamer',
#   'benefit'],
#  ['senate',
#   'bipartisan',
#   'secretsanta',
#   'exchange',
#   'bobblehead',
#   'senator',
#   'SCREEN_NAME',
#   'merry',
#   'christmas',
#   'happy',
#   'holiday'],
#  ['help',
#   'provide',
#   'healthcare',
#   'coverage',
#   'child',
#   'income',
#   'family',
#   'sufficient',
#   'funds',
#   'kansas',
#   'march',
#   'certainly',
#   'state',
#   'reauthorize'],
#  ['today', 'enrollment', 'chance', 'getcovered'],
#  ['fortbragg',
#   'spear',
#   'military',
#   'continue',
#   'important',
#   'military',
#   'installation',
#   'world'],
#  ['colleague',
#   'passionate',
#   'small_business',
#   'owner',
#   'today',
#   'goptaxbill',
#   'leaf',
#   'behind',
#   'water',
#   'street',
#   'bookstore',
#   'chocolate',
#   'type',
#   'small',
#   'first',
#   'bipartisan',
#   'reform'],
#  ['people',
#   'bipartisanship',
#   'happen',
#   'anymore',
#   'want',
#   'share',
#   'interaction',
#   'recently',
#   'SCREEN_NAME',
#   'serve',
#   'personnel',
#   'subcommittee',
#   'agree',
#   'everything',
#   'common',
#   'ground',
#   'nation',
#   'forward'],
#  ['netneutrality_protection',
#   'critical',
#   'people',
#   'hampshire',
#   'innovation',
#   'state',
#   'hampshire',
#   'fight',
#   'calling',
#   'governor',
#   'attorney',
#   'general',
#   'legal',
#   'action',
#   'protect',
#   'neutrality'],
#  ['congress',
#   'seize',
#   'important',
#   'generation',
#   'opportunity',
#   'taxreform',
#   'across',
#   'finish',
#   'SCREEN_NAME',
#   'agree'],
#  ['release',
#   'final',
#   'goptaxbill',
#   'light',
#   'clearly',
#   'try',
#   'still',
#   'corporate',
#   'special',
#   'interest',
#   'ultra',
#   'wealthy',
#   'working_family',
#   'small_business'],
#  ['thank',
#   'speaking',
#   'annette',
#   'joining',
#   'SCREEN_NAME',
#   'introduce',
#   'legislation',
#   'overturn',
#   'backward',
#   'decision',
#   'netneutrality'],
#  ['house',
#   'senate',
#   'conference_committee',
#   'release',
#   'taxreform',
#   'agreement',
#   'tonight',
#   'proposal',
#   'provide',
#   'family',
#   'small_business',
#   'relief',
#   'opportunity',
#   'state',
#   'need',
#   'forward',
#   'supporting',
#   'SCREEN_NAME'],
#  ['taxreform',
#   'broadband',
#   'meeting',
#   'virginian',
#   'details',
#   'weekly',
#   'newsletter'],
#  ['taxreform',
#   'middle',
#   'income',
#   'worker',
#   'family',
#   'across',
#   'virginia',
#   'earlier',
#   'catch',
#   'SCREEN_NAME',
#   'explain'],
#  ['take',
#   'community',
#   'effort',
#   'comprehensive',
#   'approach',
#   'crisis',
#   'recovery',
#   'SCREEN_NAME',
#   'bridge',
#   'scholarship',
#   'announcement',
#   'yesterday',
#   'provide',
#   'recover',
#   'bright',
#   'future',
#   'drugfreewv'],
#  ['SCREEN_NAME',
#   'congrats',
#   'SCREEN_NAME',
#   'winning',
#   'SCREEN_NAME',
#   'perfect',
#   'season',
#   'first',
#   'SCREEN_NAME',
#   'history'],
#  ['ridiculous',
#   'maintain',
#   'scientific',
#   'integrity',
#   'SCREEN_NAME',
#   'matter',
#   'death',
#   'SCREEN_NAME',
#   'putting',
#   'partisan',
#   'politics',
#   'first',
#   'banning',
#   'agency',
#   'using',
#   'cdc7words',
#   'evidence',
#   'base'],
#  ['higher_wages',
#   'economic',
#   'growth',
#   'taxreform',
#   'benefit',
#   'state',
#   'watch'],
#  ['taxreform', 'change', 'SCREEN_NAME', 'agree'],
#  ['deserve',
#   'award',
#   'wright',
#   'owner',
#   'SCREEN_NAME',
#   'wilmington',
#   'privilege',
#   'visiting',
#   'coffee',
#   'seeing',
#   'positive',
#   'impact',
#   'making',
#   'life',
#   'individual',
#   'disability',
#   'truly',
#   'inspire',
#   'congrats',
#   'cnnheroes'],
#  ['.@wvachamber',
#   'agree',
#   'taxreform',
#   'deliver',
#   'need',
#   'relief',
#   'virginia',
#   'business'],
#  ['netneutrality',
#   'fundamental',
#   'internet',
#   'foster',
#   'innovation',
#   'SCREEN_NAME',
#   'investigate',
#   'fraud',
#   'voting',
#   'proposal',
#   'important',
#   'SCREEN_NAME'],
#  ['december',
#   'deadline',
#   'openenrollment',
#   'approaching',
#   'today',
#   'visit',
#   'SCREEN_NAME',
#   'folks',
#   'helping',
#   'delawarean',
#   'getcovered',
#   'final',
#   'enrollment',
#   'information'],
#  ['SCREEN_NAME',
#   'enrollment',
#   'friday',
#   'december',
#   'signing',
#   'visit',
#   'getcovered'],
#  ['hampshire',
#   'state',
#   'values',
#   'innovation',
#   'netneutrality',
#   'critical',
#   'ensure',
#   'entrepreneur',
#   'level_playing',
#   'field',
#   'compete',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'fighting',
#   'innovator',
#   'savenetneutrality'],
#  ['despite',
#   'president_trump',
#   'reckless',
#   'decision',
#   'leave',
#   'standing',
#   'alone',
#   'parisagreement',
#   'leaders',
#   'across_country',
#   'standing',
#   'stillin',
#   'generation'],
#  ['republican',
#   'democratic',
#   'governor',
#   'across_country',
#   'calling',
#   'congress',
#   'renewchip',
#   'quickly',
#   'possible',
#   'believe',
#   'covering',
#   'child',
#   'pregnant',
#   'woman',
#   'without',
#   'disruption',
#   'thing',
#   'agree'],
#  ['goptaxbill',
#   'reform',
#   'process',
#   'largely',
#   'place',
#   'behind',
#   'close',
#   'door',
#   'intense',
#   'pressure',
#   'corporate',
#   'lobbyist'],
#  ['wishing', 'celebrate', 'mexico', 'across_country', 'happyhanukkah'],
#  ['three', 'visit', 'getcovered'],
#  ['getcovered', 'delaware', 'health_insurance', 'right'],
#  ['trump',
#   'SCREEN_NAME',
#   'voting',
#   'netneutrality',
#   'continue',
#   'standing',
#   'savenetneutrality'],
#  ['SCREEN_NAME',
#   'morning',
#   'trowbridge',
#   'talking',
#   'netneutrality',
#   'access_internet',
#   'important',
#   'mexican'],
#  ['jones',
#   'seat',
#   'backward',
#   'goptaxbill',
#   'bring',
#   'people',
#   'alabama',
#   'deserve',
#   'voice_hear'],
#  ['SCREEN_NAME',
#   'refuse',
#   'dreamactnow',
#   'protectdreamers',
#   'business',
#   'economy',
#   'suffer'],
#  ['given',
#   'implication',
#   'country',
#   'final',
#   'goptaxscam',
#   'jones',
#   'swear',
#   'senate'],
#  ['reason',
#   'support',
#   'netneutrality',
#   'internet',
#   'important',
#   'supporting',
#   'innovation',
#   'innovator'],
#  ['goptaxbill',
#   'together',
#   'without',
#   'talking',
#   'democrat',
#   'conference_committee',
#   'another',
#   'affront',
#   'regular',
#   'order'],
#  ['excite',
#   'progress',
#   'sagamore',
#   'project',
#   'large',
#   'result',
#   'hundred',
#   'cleanenergy',
#   'affordable',
#   'electric',
#   'bill',
#   'consumer'],
#  ['protect',
#   'precious',
#   'habitat',
#   'arctic',
#   'refuge',
#   'offering',
#   'destruction',
#   'goptaxbill',
#   'colleague',
#   'reconsider',
#   'choose',
#   'protectthearctic'],
#  ['SCREEN_NAME',
#   'still',
#   'prevent',
#   'goptaxscam',
#   'watch',
#   'wheel',
#   'misfortune',
#   'big',
#   'loser',
#   'would',
#   'repub'],
#  ['internet',
#   'critical',
#   'everything',
#   'entrepreneurship',
#   'online',
#   'activism',
#   'heading',
#   'senate_floor',
#   'speak',
#   'SCREEN_NAME',
#   'attempt',
#   'repeal_netneutrality'],
#  ['watch', 'senate_floor', 'speaking', 'repeal_netneutrality'],
#  ['demand',
#   'dreamactnow_americandreamer',
#   'yadira',
#   'crux',
#   'small_business',
#   'owner',
#   'mother',
#   'three',
#   'continue',
#   'contribute',
#   'economy'],
#  ['standing', 'americandreamer', 'karla', 'mexico', 'fighting', 'dreamactnow'],
#  ['dreamactnow',
#   'dreamer',
#   'young',
#   'recently',
#   'office',
#   'attend',
#   'community',
#   'college',
#   'eventually',
#   'enroll',
#   'beyond',
#   'protect',
#   'dreamer',
#   'across_america'],
#  ['goptaxscam',
#   'hurt',
#   'working_family',
#   'future_generation',
#   'anyone',
#   'pay',
#   'state',
#   'local',
#   'tax',
#   'public',
#   'school',
#   'people',
#   'disaster',
#   'stricken',
#   'area',
#   'charity',
#   'firefighter',
#   'police',
#   'officer',
#   'local',
#   'community',
#   'small'],
#  ['SCREEN_NAME',
#   'goptaxscam',
#   'give',
#   'giveaway',
#   'wealthy',
#   'large_corporation',
#   'process'],
#  ['SCREEN_NAME',
#   'thank',
#   'SCREEN_NAME',
#   'standing_solidarity',
#   'dreamer_democrat'],
#  ['getcovered', 'running', 'start'],
#  ['young', 'woman', 'neighbor', 'friend', 'dreamer', 'congress_dreamactnow'],
#  ['individual',
#   'spend',
#   'career',
#   'advocate',
#   'protective',
#   'chemical',
#   'safety',
#   'standard',
#   'business',
#   'leading',
#   'SCREEN_NAME',
#   'chemical',
#   'safety',
#   'office',
#   'withdrawal',
#   'michael',
#   'dourson',
#   'nomination',
#   'interest',
#   'american'],
#  ['SCREEN_NAME',
#   'withdrawal',
#   'dourson',
#   'nomination',
#   'serve',
#   'lesson',
#   'senate',
#   'opportunity',
#   'together',
#   'independent',
#   'credible',
#   'chemical',
#   'safety',
#   'regulator',
#   'protect',
#   'public',
#   'health',
#   'implementation',
#   'bipartisan',
#   'reform'],
#  ['republican',
#   'colleague',
#   'listen',
#   'american_people',
#   'rushing',
#   'ahead',
#   'goptaxscam',
#   'democrat',
#   'renewchip',
#   'instead'],
#  ['SCREEN_NAME',
#   'netneutrality',
#   'today',
#   'impact',
#   'mexico',
#   'absolutely',
#   'cripple',
#   'small_business',
#   'mexico',
#   'across_country'],
#  ['internet', 'load', 'protect', 'netneutrality'],
#  ['gutting', 'netneutrality', 'wreck', 'internet', 'happen'],
#  ['years',
#   'unthinkable',
#   'tragedy',
#   'sandy',
#   'elementary_school',
#   'continue',
#   'mourn',
#   'life',
#   'family',
#   'friend',
#   'neighbor',
#   'honorwithaction',
#   'endgunviolence'],
#  ['SCREEN_NAME',
#   'today',
#   'years',
#   'since',
#   'tragedy',
#   'sandyhook',
#   'elementary_school',
#   'newtown',
#   'dark',
#   'moment'],
#  ['SCREEN_NAME',
#   'voting',
#   'netneutrality',
#   'right',
#   'unnoticed',
#   'every',
#   'american',
#   'access_internet',
#   'impact',
#   'decision',
#   'watch'],
#  ['internet',
#   'portal',
#   'communication',
#   'commerce',
#   'change',
#   'learn',
#   'living',
#   'love',
#   'place',
#   'everyone',
#   'equal',
#   'access',
#   'protect',
#   'netneutrality'],
#  ['SCREEN_NAME',
#   'netneutrality',
#   'american',
#   'another',
#   'example',
#   'trump_admin',
#   'gutting',
#   'commonsense',
#   'protection',
#   'ignore',
#   'people'],
#  ['netneutrality',
#   'essential',
#   'fostering',
#   'innovation',
#   'education',
#   'promote',
#   'civic',
#   'engagement',
#   'continue',
#   'fighting',
#   'savenetneutrality'],
#  ['SCREEN_NAME',
#   'vote',
#   'netneutrality',
#   'today',
#   'fight',
#   'joining',
#   'SCREEN_NAME',
#   'restore',
#   'vital',
#   'netneutrality_rule',
#   'everything',
#   'savenetneutrality'],
#  ['asking', 'administration', 'everyone', 'want', 'getcovered', 'opportunity'],
#  ['republican',
#   'try',
#   'sneak',
#   'provision',
#   'arctic',
#   'drilling',
#   'goptaxscam',
#   'refuge',
#   'drilling',
#   'protectthearctic'],
#  ['SCREEN_NAME',
#   'want',
#   'arcticrefuge',
#   'drilling',
#   'goptaxscam',
#   'recent',
#   'drilling',
#   'alaska'],
#  ['demand', 'people', 'alabama', 'hear', 'goptaxscam'],
#  ['matter',
#   'continue',
#   'working',
#   'firearm',
#   'hands',
#   'would',
#   'family',
#   'friend',
#   'neighbor',
#   'honorwithaction'],
#  ['delawarean', 'today', 'openenrollment', 'right', 'health', 'getcovered'],
#  ['retweet', 'spread', 'today', 'getcovered', 'health_coverage'],
#  ['since',
#   'expire',
#   'republican',
#   'playing',
#   'game',
#   'child_health',
#   'extendchip'],
#  ['delaware',
#   'state',
#   'expect',
#   'money',
#   'january',
#   'thousand',
#   'delawarean',
#   'child',
#   'million',
#   'across_country',
#   'counting',
#   'congress',
#   'fundchipnow'],
#  ['try', 'getcovered', 'speak', 'representative'],
#  ['americandreamer',
#   'educator',
#   'oriandi',
#   'lose',
#   'continue',
#   'serving',
#   'student',
#   'family',
#   'dreamer',
#   'student'],
#  ['SCREEN_NAME',
#   'today',
#   'deadline_getcovered',
#   'affordable',
#   'health_coverage',
#   'right'],
#  ['finally',
#   'december',
#   'lastjedi',
#   'today',
#   'getcovered',
#   'today',
#   'affordable',
#   'health_coverage',
#   'force'],
#  ['goptaxscam',
#   'rural',
#   'community',
#   'investing',
#   'speed',
#   'internet',
#   'helping',
#   'small',
#   'ensure',
#   'family',
#   'afford',
#   'college',
#   'health_coverage',
#   'SCREEN_NAME'],
#  ['SCREEN_NAME',
#   'instead',
#   'goptaxscam',
#   'invest',
#   'community',
#   'focus',
#   'program',
#   'prove',
#   'reduce',
#   'poverty',
#   'incentivize',
#   'earn',
#   'income',
#   'credit',
#   'child',
#   'credit',
#   'effectively',
#   'raise',
#   'income',
#   'working_family'],
#  ['goptaxscam',
#   'trigger',
#   'billion',
#   'automatic',
#   'medicare',
#   'would',
#   'devastate',
#   'million',
#   'senior',
#   'include',
#   'cancer',
#   'patient',
#   'depend',
#   'medicare',
#   'health'],
#  ['SCREEN_NAME',
#   'calling',
#   'delawarean',
#   'enrollment_period',
#   'midnight',
#   'getcovered',
#   'http'],
#  ['SCREEN_NAME',
#   'please',
#   'drive',
#   'safely',
#   'allow',
#   'extra',
#   'brake',
#   'distance',
#   'plow',
#   'plenty',
#   'roads',
#   'snowde'],
#  ['shameful',
#   'republican',
#   'refusal',
#   'dreamactnow',
#   'strip',
#   '12,276',
#   'dreamer',
#   'protect',
#   'status'],
#  ['urgent',
#   'dreamer',
#   'lose',
#   'protection',
#   'every',
#   'SCREEN_NAME',
#   'dreamactnow'],
#  ['SCREEN_NAME', 'hours', 'health_coverage', 'getcovered', 'https:/'],
#  ['member',
#   'congress',
#   'dreamer',
#   'without',
#   'nation',
#   'continue',
#   'stand',
#   'withdreamers',
#   'colleague',
#   'congress_dreamactnow'],
#  ['continue',
#   'closely',
#   'monitor',
#   'wildfire',
#   'custer',
#   'state',
#   'endless',
#   'thanks',
#   'emergency',
#   'crew',
#   'firefighter',
#   'across',
#   'black',
#   'hill',
#   'working',
#   'difficult',
#   'weather',
#   'conditions',
#   'contain'],
#  ['december',
#   'indiana',
#   'become',
#   'nation',
#   'state',
#   'today',
#   'celebrate',
#   'years',
#   'hoosier',
#   'values',
#   'happy_birthday',
#   'indiana',
#   'indianastatehoodday'],
#  ['domesticviolenceloophole',
#   'widespread',
#   'problem',
#   'close',
#   'arm',
#   'services',
#   'american',
#   'safe.@jacqklimas'],
#  ['responsible',
#   'manage',
#   'million',
#   'acres',
#   'publicland',
#   'director',
#   'respects',
#   'state',
#   'public_land',
#   'legacy'],
#  ['public_land',
#   'belong',
#   'public',
#   'hands',
#   'disgraceful',
#   'trump_admin',
#   'attack',
#   'bearsears',
#   'grandstaircase',
#   'arcticrefuge'],
#  ['earlier',
#   'today',
#   'join',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'discus',
#   'steps',
#   'taxreform',
#   'confident',
#   'deliver',
#   'american_people',
#   'deserve'],
#  ['minute', 'check', 'newsletter', 'taxrelief', 'event', 'indiana'],
#  ['today',
#   'SCREEN_NAME',
#   'sign',
#   'fiscal',
#   'important',
#   'piece',
#   'legislation',
#   'authorize',
#   'funding',
#   'arm',
#   'force',
#   'successfully',
#   'carry',
#   'mission'],
#  ['trump',
#   'SCREEN_NAME',
#   'ignore',
#   'experts’',
#   'warning',
#   'ignore',
#   'million_american',
#   'calling',
#   'netneutrality',
#   'remain',
#   'protect'],
#  ['working',
#   'close',
#   'digitaldivide',
#   'student',
#   'child',
#   'tribal',
#   'community',
#   'access_internet',
#   'opportunity',
#   'provide',
#   'tribalconnect'],
#  ['today',
#   'letter',
#   'chairman',
#   'urging',
#   'abandon',
#   'reckless',
#   'radically',
#   'alter',
#   'internet',
#   'critically',
#   'important',
#   'savenetneutrality',
#   'protect',
#   'consumer',
#   'future',
#   'internet'],
#  ['internet',
#   'bring',
#   'people',
#   'together',
#   'thousand',
#   'mile',
#   'educate',
#   'across',
#   'nation',
#   'provide',
#   'countless',
#   'hours',
#   'entertainment',
#   'savenetneutrality',
#   'protect',
#   'internet'],
#  ['people',
#   'determine',
#   'internet',
#   'certain',
#   'content',
#   'simple',
#   'savenetneutrality'],
#  ['grateful',
#   'amber',
#   'sharing',
#   'experience',
#   'caregiver',
#   'please',
#   'provision',
#   'include',
#   'caregiver',
#   'transition',
#   'process',
#   'sign',
#   'today'],
#  ['republican',
#   'try',
#   'book',
#   'goptaxscam',
#   'massive',
#   'giveaway',
#   'wealthy',
#   'middle_class',
#   'family',
#   'force'],
#  ['calling',
#   'SCREEN_NAME',
#   'chairman',
#   'SCREEN_NAME',
#   'abandon',
#   'reckless',
#   'netneutrality',
#   'future',
#   'internet',
#   'hang',
#   'balance',
#   'savenetneutrality'],
#  ['happy_hanukkah', 'wish'],
#  ['protection',
#   'nation',
#   'civil',
#   'right',
#   'president_trump',
#   'judicial_nominee',
#   'civil',
#   'right',
#   'record',
#   'woman',
#   'american',
#   'deserve',
#   'better',
#   'badforwomen_courtsmatter'],
#  ['SCREEN_NAME',
#   'urgent',
#   'close',
#   'digitaldivide',
#   'tribal',
#   'community',
#   'nation',
#   'SCREEN_NAME'],
#  ['SCREEN_NAME',
#   'happy_hanukkah',
#   'sameach',
#   'celebrate',
#   'america',
#   'israel',
#   'around_world'],
#  ['sign',
#   'SCREEN_NAME',
#   'today',
#   'include',
#   'priority',
#   'work',
#   'include',
#   'learn',
#   '--&gt'],
#  ['middle', 'income', 'american', 'earn', 'dollar', 'taxcutsandjobsact'],
#  ['wishing_happy', 'hanukkah_celebrate', 'indiana', 'across', 'world'],
#  ['wishing_happy', 'hanukkah_celebrate', 'montana', 'around_world'],
#  ['people',
#   'wyoming',
#   'across_country',
#   'relief',
#   'tax',
#   'business',
#   'competitive',
#   'economy',
#   'create',
#   'taxreform'],
#  ['important',
#   'exchange',
#   'today',
#   'senate',
#   'foreign',
#   'relations',
#   'committee'],
#  ['congratulations',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'victory',
#   'wtpindiana',
#   'state',
#   'final',
#   'proud',
#   'young',
#   'hoosier',
#   'interest',
#   'studying',
#   'constitution'],
#  ['spoke',
#   'SCREEN_NAME',
#   'growth',
#   'taxreform',
#   'going',
#   'directly',
#   'lower',
#   'burden',
#   'working_family',
#   'middle',
#   'income',
#   'family',
#   'people',
#   'paycheck',
#   'paycheck',
#   'topic'],
#  ['honor',
#   'receive',
#   'lifetime',
#   'achievement',
#   'award',
#   'washington',
#   'proud',
#   'continue',
#   'fight',
#   'behalf',
#   'working',
#   'folks',
#   'wyoming',
#   'industry'],
#  ['SCREEN_NAME',
#   'artificialintelligence',
#   'scare',
#   'people',
#   'SCREEN_NAME',
#   'federal',
#   'government',
#   'making',
#   'policy'],
#  ['bipartisan',
#   'secretsanta',
#   'exchange',
#   'tonight',
#   'SCREEN_NAME',
#   'bring',
#   'SCREEN_NAME',
#   'thank'],
#  ['dreamer',
#   'neighbor',
#   'friend',
#   'valedictorian',
#   'first',
#   'responder',
#   'country',
#   'together',
#   'acknowledge',
#   'nation',
#   'strong',
#   'instead',
#   'try',
#   'country',
#   'know'],
#  ['SCREEN_NAME',
#   'taxreform',
#   'increase',
#   'child',
#   'credit',
#   'lower',
#   'burden',
#   'every',
#   'category',
#   'income',
#   'earner'],
#  ['icymi',
#   'weekly',
#   'column',
#   'celebrate',
#   'adoption',
#   'making',
#   'dream',
#   'family',
#   'reality',
#   'SCREEN_NAME'],
#  ['statement', 'fifth', 'anniversary', 'sandyhook'],
#  ['murphy', 'statement', 'decision', 'repeal_netneutrality'],
#  ['coming',
#   'shortly',
#   'joining',
#   'SCREEN_NAME',
#   'mtpdaily',
#   'discus',
#   'taxreform',
#   'SCREEN_NAME',
#   'watch'],
#  ['republican',
#   'people',
#   'wyoming',
#   'anyone',
#   'want',
#   'earn',
#   'money',
#   'taxreform'],
#  ['SCREEN_NAME',
#   'SCREEN_NAME',
#   'miss',
#   'watch',
#   'segment',
#   'mtpdaily',
#   'SCREEN_NAME',
#   'spoke',
#   'virtually',
#   'every',
#   'working',
#   'class',
#   'middle',
#   'income',
#   'family',
#   'significant'],
#  ['animal',
#   'crushing',
#   'blatantly',
#   'inhumane',
#   'astonishingly',
#   'cruel',
#   'work',
#   'SCREEN_NAME',
#   'bipartisan',
#   'pactact',
#   'pass',
#   'senate',
#   'heinous',
#   'practice'],
#  ['today',
#   'marks',
#   'years',
#   'since',
#   'ratification',
#   'right',
#   'constitution',
#   'happy',
#   'billofrightsday'],
#  ['join',
#   'SCREEN_NAME',
#   'director',
#   'SCREEN_NAME',
#   'sioux',
#   'falls',
#   'morning',
#   'taxcutsandjobsact',
#   'provide',
#   'bigger',
#   'paycheck',
#   'fair',
#   'system',
#   'watch'],
#  ['moment',
#   'generation',
#   'opportunity',
#   'money',
#   'hands',
#   'hardworking',
#   'american',
#   'taxcutsandjobsact'],
#  ['cutting',
#   'tax',
#   'family',
#   'street',
#   'business',
#   'start',
#   'economy',
#   'door',
#   'creation',
#   'pay',
#   'taxcutsandjobsact'],
#  ['harrisonburg',
#   'today',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'semifinal',
#   'matchup',
#   'afternoon',
#   'gojacks'],
#  ['staffer',
#   'wreath',
#   'SCREEN_NAME',
#   'morning',
#   'thank',
#   'SCREEN_NAME',
#   'opportunity',
#   'honor',
#   'nation',
#   'veteran',
#   'waa2017'],
#  ['local',
#   'casper',
#   'volunteer',
#   'incredible',
#   'place',
#   'wreath',
#   'every',
#   'grave',
#   'oregon',
#   'trail',
#   'state',
#   'veteran',
#   'cemetery',
#   'today',
#   'SCREEN_NAME',
#   'america',
#   'great',
#   'honor',
#   'serve',
#   'waa2017'],
#  ['close',
#   'passing',
#   'growth',
#   'taxreform',
#   'benefit',
#   'family',
#   'stimulate',
#   'economy',
#   'miss',
#   'outline',
#   'goal',
#   'SCREEN_NAME',
#   'week'],
#  ['congrats',
#   'SCREEN_NAME',
#   'incredible',
#   'ranking',
#   'SCREEN_NAME',
#   'basketball',
#   'first',
#   'ranking',
#   'since',
#   'forksup'],
#  ['imagine',
#   'country',
#   'commit',
#   'uphold',
#   'promise',
#   'wrong',
#   'plain',
#   'simple',
#   'dreamact'],
#  ['great',
#   'photo',
#   'armynavygame',
#   'SCREEN_NAME',
#   'tradition',
#   'knight',
#   'remember',
#   'philadelphia'],
#  ['right',
#   'hundred',
#   'thousand',
#   'dreamer',
#   'nationwide',
#   'defer',
#   'dream',
#   'college',
#   'start',
#   'business',
#   'serve',
#   'military',
#   'president_trump',
#   'reckless',
#   'decision',
#   'program',
#   'dreamact'],
#  ['trump',
#   'judicial_nominee',
#   'fight',
#   'weaken',
#   'protection',
#   'sexual',
#   'harassment',
#   'assault',
#   'badforwomen'],
#  ['today',
#   'SCREEN_NAME',
#   'sign',
#   'fy18ndaa',
#   'authorize',
#   'rebuild',
#   'military',
#   'congress',
#   'white',
#   'house',
#   'quickly',
#   'negotiate',
#   'bipartisan',
#   'budget',
#   'agreement',
#   'secure',
#   'critical',
#   'funding',
#   'troops'],
#  ['SCREEN_NAME',
#   'today',
#   'SCREEN_NAME',
#   'sign',
#   'serviceman',
#   'woman',
#   'resource',
#   'country'],
#  ['SCREEN_NAME',
#   'president',
#   'sign',
#   'fy18ndaa',
#   'authorize',
#   'resource',
#   'policy',
#   'necessary',
#   'service'],
#  ['family', 'struggle', 'afford', 'child', 'childcare4all', 'costofcare17'],
#  ['affordable',
#   'child',
#   'working_family',
#   'right_thing',
#   'smart',
#   'investment',
#   'costofcare17'],
#  ['across',
#   'finish',
#   'hundred',
#   'thousand',
#   'dreamer',
#   'nationwide',
#   'fighting',
#   'shadow',
#   'dreamact'],
#  ['happy_hanukkah', 'blessing', 'celebrate_festival', 'light'],
#  ['SCREEN_NAME',
#   'thomasfire',
#   'update',
#   'north',
#   'santa',
#   'paula',
#   'ventura',
#   'county',
#   '237,500',
#   'acres',
#   'contain',
#   'unifi'],
#  ['SCREEN_NAME',
#   'need',
#   'delay',
#   'netneutrality',
#   'examine',
#   'could',
#   'nation',
#   'student',
#   'school',
#   'especially',
#   'rural',
#   'income',
#   'community'],
#  ['another',
#   'symptom',
#   'republican',
#   'rush',
#   'partisan',
#   'could',
#   'potentially',
#   'devastate',
#   'arctic',
#   'refuge',
#   'nation',
#   'natural',
#   'treasure',
#   'protectthearctic'],
#  ['report',
#   'trump_admin',
#   'willing',
#   'accept',
#   'years',
#   'assad',
#   'syria',
#   'deeply',
#   'disturb',
#   'would',
#   'validate',
#   'facto',
#   'policy',
#   'successive',
#   'admins',
#   'fail',
#   'slaughter'],
#  ['awful',
#   'provision',
#   'goptaxplan',
#   'would',
#   'allow',
#   'drilling',
#   'pristine',
#   'arctic',
#   'national',
#   'wildlife',
#   'refuge'],
#  ['climate_change',
#   'wreak',
#   'havoc',
#   'arctic',
#   'would',
#   'habitat',
#   'jeopardy',
#   'accelerate',
#   'global',
#   'warming',
#   'protectthearctic'],
#  ['stand',
#   'dreamer',
#   'immigrant',
#   'community',
#   'raise',
#   'voice',
#   'policy',
#   'rhetoric',
#   'friend',
#   'neighbor',
#   'coworkers',
#   'student',
#   'love',
#   'dreamact'],
#  ['future_generation',
#   'access',
#   'enjoy',
#   'public_land',
#   'protect',
#   'wonder',
#   'arcticrefuge',
#   'drilling',
#   'reason',
#   'fight'],
#  ['internet',
#   'access',
#   'especially',
#   'critical',
#   'rural',
#   'area',
#   'everything',
#   'affordable',
#   'accessible',
#   'protect',
#   'netneutrality'],
#  ['partisan',
#   'process',
#   'brazen',
#   'partisan',
#   'attempt',
#   'would',
#   'devastate',
#   'economy',
#   'little',
#   'scrutiny',
#   'debate',
#   'possible',
#   'regular',
#   'order',
#   'today',
#   'fool',
#   'anyone',
#   'goptaxscam'],
#  ['president_trump',
#   'SCREEN_NAME',
#   'larger',
#   'profits',
#   'large_corporation',
#   'internet',
#   'available',
#   'fight',
#   'netneutrality_rule'],
#  ['ventura',
#   'county',
#   'local',
#   'assistance',
#   'center',
#   'affect',
#   'devastate',
#   'thomasfire',
#   'official',
#   'standing',
#   'ready'],
#  ['today',
#   'fifth',
#   'anniversary',
#   'shooting',
#   'sandyhook',
#   'elementary_school',
#   'twenty',
#   'child',
#   'educator',
#   'slaughter',
#   'SCREEN_NAME',
#   'cover',
#   'office',
#   'child',
# ...
#   'pamela',
#   'share',
#   'big',
#   'lesson',
#   'learn',
#   'member',
#   'infantry',
#   'brigade',
#   'SCREEN_NAME',
#   'veteranshistoryproject'],
#  ['great',
#   'nearly',
#   'company',
#   'align',
#   'emission',
#   'reduction',
#   'plan',
#   'parisagreement',
#   'clear',
#   'administration',
#   'country',
#   'across',
#   'globe',
#   'climatechange',
#   'threaten',
#   'economy',
#   'future',
#   'planet'],
#  ['speaking',
#   'senatefloor',
#   'continue',
#   'tribute',
#   'nebraska',
#   'hero',
#   'life',
#   'defend',
#   'freedom',
#   'afghanistan',
#   'today',
#   'honor',
#   'service',
#   'chief',
#   'warrant',
#   'officer',
#   'christopher',
#   'allgaier',
#   'omaha'],
#  ['growing',
#   'chris',
#   'live',
#   'pretty',
#   'typical',
#   'nebraska',
#   'favorite',
#   'pizza',
#   'place',
#   'family',
#   'cheer',
#   'huskers',
#   'attend',
#   'robert',
#   'bellarmine',
#   'catholic',
#   'church',
#   'omaha',
#   'parent',
#   'sister',
#   'sharon',
#   'brother'],
#  ['shortly',
#   'receive',
#   'bachelor',
#   'degree',
#   'chris',
#   'enlist',
#   'SCREEN_NAME',
#   'graduate',
#   'basic',
#   'combat',
#   'training',
#   'jackson',
#   'attending',
#   'advance',
#   'individual',
#   'training',
#   'aviation',
#   'mechanics',
#   'service'],
#  ['night',
#   'chris',
#   'night',
#   'operation',
#   'transport',
#   'approximately',
#   'service',
#   'member',
#   'shortly',
#   'drop',
#   'soldier',
#   'important',
#   'mission',
#   'insurgent',
#   'ch-47',
#   'chinook',
#   'killing',
#   'chris',
#   'service',
#   'member',
#   'neheroes'],
#  ['chief',
#   'warrant',
#   'officer',
#   'allgaier',
#   'memorial',
#   'service',
#   'catholic',
#   'church',
#   'omaha',
#   'hundred',
#   'people',
#   'include',
#   'hundred',
#   'patriotriders',
#   'turn',
#   'final',
#   'respects'],
#  ['chief',
#   'warrant',
#   'officer',
#   'chris',
#   'allgaier',
#   'award',
#   'bronze',
#   'purple',
#   'heart',
#   'posthumously',
#   'nebraskan',
#   'american',
#   'across_country',
#   'salute',
#   'willingness',
#   'family',
#   'sacrifice',
#   'proudnebraskan',
#   'neheroes'],
#  ['great',
#   'SCREEN_NAME',
#   'young',
#   'farmer',
#   'rancher',
#   'discus',
#   'important',
#   'agriculture',
#   'community',
#   'great',
#   'young_people',
#   'helping',
#   'farming',
#   'generation'],
#  ['goptaxbill',
#   'conference_committee',
#   'throw',
#   'arcticrider',
#   'shortsighted',
#   'expensive',
#   'deeply',
#   'unpopular',
#   'protect',
#   'greatest',
#   'national',
#   'treasure',
#   'exploit',
#   'protectthearctic'],
#  ['letter',
#   'SCREEN_NAME',
#   'annetta',
#   'coffman',
#   'importance',
#   'battle',
#   'cancer',
#   'senate',
#   'partisanship',
#   'aside',
#   'secure',
#   'funding'],
#  ['proud',
#   'arkansan',
#   'represent',
#   'SCREEN_NAME',
#   'championship',
#   'poland',
#   'work',
#   'opportunity',
#   'represent',
#   'arkansas',
#   'country'],
#  ['dreamer',
#   'lose',
#   'status_every',
#   'black',
#   'website',
#   'solidarity_dreamer',
#   'signal',
#   'pay',
#   'attention',
#   'letting',
#   'protect',
#   'future',
#   'defenddaca'],
#  ['office',
#   'receive',
#   'nearly',
#   '25,000',
#   'letters',
#   'call',
#   'coloradan',
#   'netneutrality',
#   'consensus',
#   'could',
#   'clear',
#   'protect',
#   'internet',
#   'morning',
#   'letter',
#   'SCREEN_NAME',
#   'final',
#   'attempt',
#   'protectnetneutrality'],
#  ['minute', 'chart', 'review', 'speaking', 'SCREEN_NAME', 'goptaxbill'],
#  ['SCREEN_NAME',
#   'dreamer',
#   'brittany',
#   'join',
#   'SCREEN_NAME',
#   'SCREEN_NAME',
#   'congress_dreamactnow'],
#  ['fighting',
#   'dreamactnow',
#   'important',
#   'priority',
#   'young_people',
#   'brittany'],
#  ['work',
#   'bipartisan',
#   'could',
#   'write',
#   'taxbill',
#   'actually',
#   'tax',
#   'middle_class',
#   'expand',
#   'childtaxcredit',
#   'make',
#   'economy',
#   'competitive',
#   'invest',
#   'future',
#   'scrap',
#   'goptaxbill'],
#  ['SCREEN_NAME',
#   'suppose',
#   'protect',
#   'consumer',
#   'public',
#   'interest',
#   'nation',
#   'communications',
#   'network',
#   'fail',
#   'mission',
#   'today',
#   'fight_savenetneutrality'],
#  ['sandyhook',
#   'unspeakable',
#   'tragedy',
#   'never',
#   'normal',
#   'condition',
#   'american',
#   'later',
#   'take',
#   'action',
#   'belief',
#   'within',
#   'power',
#   'protect',
#   'school',
#   'night',
#   'concert',
#   'honorwithaction'],
#  ['12,000',
#   'dreamer',
#   'brittany',
#   'already',
#   'status',
#   'dreamactnow',
#   'longer'],
#  ['today',
#   'ambassador',
#   'SCREEN_NAME',
#   'discus',
#   'recently',
#   'pass',
#   'fy18ndaa',
#   'country',
#   'longer',
#   'history',
#   'partnership',
#   'forward',
#   'productive',
#   'conversation',
#   'future'],
#  ['SCREEN_NAME',
#   'thank',
#   'senator',
#   'SCREEN_NAME',
#   'asking',
#   'question',
#   'courtsmatter',
#   'kacsmaryk',
#   'nearly',
#   'colorful'],
#  ['today',
#   'host',
#   'roundtable',
#   'discussion',
#   'explore',
#   'relationship',
#   'agriculture',
#   'hear',
#   'testimony',
#   'nestakeholders',
#   'government',
#   'official',
#   'industry',
#   'expert',
#   'policy',
#   'government',
#   'pursue',
#   'advance',
#   'help',
#   'feedtheworld'],
#  ['congrats',
#   'SCREEN_NAME',
#   'championship',
#   'witheachotherforeachother',
#   'girlpower'],
#  ['congrats',
#   'nebraska',
#   'national',
#   'guard',
#   '155th',
#   'refueling',
#   'hustle',
#   'huskers',
#   'winning',
#   'SCREEN_NAME',
#   'outstanding',
#   'award',
#   'proudnebraskan',
#   'great',
#   'story',
#   'SCREEN_NAME',
#   'honor'],
#  ['great',
#   'weekend',
#   'visit',
#   'SCREEN_NAME',
#   'pocahontas',
#   'county',
#   'reporting',
#   'december',
#   'conditions',
#   'decade',
#   'beginning',
#   'tomorrow',
#   'host',
#   'winter',
#   'brewfest',
#   'variety',
#   'craft',
#   'beer',
#   'thisiswv'],
#  ['health_insurance',
#   'start',
#   'january',
#   'colorado',
#   'today',
#   'information',
#   'enrollment',
#   'private',
#   'insurance',
#   'SCREEN_NAME',
#   'continue',
#   'january',
#   'enroll',
#   'today',
#   'getcovered'],
#  ['dreamer', 'status_every', 'congress', 'longer', 'dreamactnow'],
#  ['breaking',
#   'paidfamilyleave',
#   'include',
#   'final',
#   'taxreform',
#   'conference_report',
#   'truly',
#   'historic',
#   'measure',
#   'statement'],
#  ['SCREEN_NAME',
#   'tonight',
#   'SCREEN_NAME',
#   'woman',
#   'volleyball',
#   'championship',
#   'SCREEN_NAME'],
#  ['goptaxbill',
#   'colorado',
#   'middle_class',
#   'family',
#   'benefit',
#   'daughter',
#   'trillion',
#   'instead',
#   'invest',
#   'solution',
#   'address',
#   'challenge',
#   'facing',
#   'infrastructure',
#   'opioidcrisis'],
#  ['tomorrow', 'morning', 'catch', 'SCREEN_NAME', 'SCREEN_NAME', 'ifitssunday'],
#  ['congrats',
#   'SCREEN_NAME',
#   'winning',
#   'national',
#   'championship',
#   'girlpower',
#   'witheachotherforeachother',
#   'nationalchamps',
#   'proudnebraskan'],
#  ['minutes', 'joining', 'SCREEN_NAME', 'SCREEN_NAME', 'ifitssunday'],
#  ['icymi',
#   'join',
#   'SCREEN_NAME',
#   'morning',
#   'SCREEN_NAME',
#   'democrat',
#   'effort',
#   'across',
#   'aisle',
#   'tax'],
#  ['nearly',
#   'basic',
#   'medical',
#   'prescription',
#   'immunization',
#   'dental',
#   'vision',
#   'mental',
#   'health_coverage',
#   'SCREEN_NAME'],
#  ['today',
#   '12,519',
#   'dreamer',
#   'status',
#   'hundred',
#   'thousand',
#   'opportunity',
#   'attend',
#   'school',
#   'receive',
#   'permit',
#   'driver',
#   'license',
#   'contribute',
#   'community',
#   'rip',
#   'bipartisan',
#   'solution',
#   'americandreamer'],
#  ['SCREEN_NAME',
#   'week',
#   'since',
#   'SCREEN_NAME',
#   'pass',
#   'goptaxscam',
#   'corporation',
#   'announce',
#   'billion',
#   'stock',
#   'buyback',
#   'clear',
#   'signal'],
#  ['another',
#   'crucial',
#   'funding',
#   'community',
#   'health',
#   'center',
#   'still',
#   'renew',
#   'making',
#   'continue',
#   'protect',
#   'family',
#   'child',
#   'michigan'],
#  ['request',
#   'investigation',
#   'SCREEN_NAME',
#   'finally',
#   'release',
#   'analysis',
#   'goptaxscam',
#   'report',
#   'pathetic',
#   'show',
#   'secretary',
#   'mnuchin',
#   'basis',
#   'claim',
#   'growth'],
#  ['recap',
#   'claim',
#   'repeatedly',
#   'projection',
#   'showing',
#   'goptaxscam',
#   'mnuchin',
#   'release',
#   'report',
#   'showing',
#   'projection',
#   'wildly',
#   'optimistic',
#   'projection',
#   'enough'],
#  ['american_people',
#   'deserve',
#   'goptaxscam',
#   'impact',
#   'economy',
#   'affect',
#   'middle_class',
#   'family',
#   'SCREEN_NAME',
#   'promise',
#   'economic',
#   'analysis',
#   'forward',
#   'investigation',
#   'provide',
#   'answer',
#   'american',
#   'family'],
#  ['SCREEN_NAME',
#   'vitally',
#   'important',
#   'smallbiz',
#   'voice',
#   'rulemaking',
#   'process',
#   'accountability',
#   'common',
#   'sense',
#   'assessin'],
#  ['really',
#   'try',
#   'bully',
#   'intimidate',
#   'shame',
#   'SCREEN_NAME',
#   'picking',
#   'fight',
#   'SCREEN_NAME',
#   'nevertheless',
#   'shepersisted'],
#  ['wishing',
#   'jewish',
#   'friend',
#   'happy_hanukkah',
#   'fill',
#   'happiness',
#   'light',
#   'first',
#   'candle',
#   'menorah',
#   'tonight'],
#  ['SCREEN_NAME',
#   'happening',
#   'member',
#   'connie',
#   'SCREEN_NAME',
#   'extendchip',
#   'watch',
#   'http'],
#  ['netneutrality_protection',
#   'ending',
#   'internet',
#   'ability',
#   'internet',
#   'putting',
#   'internet',
#   'hands',
#   'company',
#   'instead'],
#  ['thank', 'SCREEN_NAME', 'child', 'family', 'health', 'hero', 'extendchip'],
#  ['tomorrow', 'SCREEN_NAME', 'netneutrality_rule', 'fight', 'internet'],
#  ['holding', 'access', 'event', 'tonight', 'online', 'utpol'],
#  ['december', 'access', 'event', 'starting', 'utpol'],
#  ['discuss',
#   'latest',
#   'release',
#   'report',
#   'social',
#   'capital',
#   'project',
#   'unwed',
#   'childbearing',
#   'access',
#   'event',
#   'report',
#   'utpol',
#   'SCREEN_NAME'],
#  ['access', 'event', 'discuss', 'change', 'bear', 'monument', 'utpol'],
#  ['today',
#   'years',
#   'since',
#   'tragedy',
#   'sandyhook',
#   'elementary_school',
#   'newtown',
#   'dark',
#   'moment',
#   'nation',
#   'history'],
#  ['stand',
#   'sandyhook',
#   'family',
#   'show',
#   'unparalleled',
#   'courage',
#   'resilience',
#   'unimaginable',
#   'grief',
#   'never',
#   'forget',
#   'innocent',
#   'life',
#   'years',
#   'today'],
#  ['today',
#   'every',
#   'honor',
#   'victim',
#   'tragedy',
#   'sandyhook',
#   'action',
#   'scourge',
#   'violence',
#   'never',
#   'fight',
#   'honorwithaction'],
#  ['heading',
#   'senate_floor',
#   'speak',
#   'fifth',
#   'anniversary',
#   'sandyhook',
#   'facebook'],
#  ['today',
#   'overturn',
#   'netneutrality_protection',
#   'terrible',
#   'american',
#   'equal',
#   'access_internet',
#   'introduce_resolution',
#   'SCREEN_NAME',
#   'others',
#   'reverse',
#   'decision'],
#  ['trump',
#   'deal',
#   'major',
#   'internet',
#   'repeal_netneutrality',
#   'rule',
#   'chairman',
#   'republican',
#   'commissioner',
#   'longer',
#   'rule',
#   'place',
#   'internet',
#   'service',
#   'provider',
#   'change',
#   'internet'],
#  ['today',
#   'rollback',
#   'netneutrality',
#   'brazen',
#   'betrayal',
#   'american',
#   'consumer',
#   'innovator',
#   'student',
#   'entrepreneur',
#   'suffer',
#   'tremendously',
#   'without',
#   'internet'],
#  ['undoing',
#   'netneutrality',
#   'early',
#   'christmas',
#   'present',
#   'internet',
#   'service',
#   'provider',
#   'block',
#   'content',
#   'speed',
#   'charge',
#   'higher',
#   'access'],
#  ['trump_administration',
#   'fashion',
#   'everyday',
#   'american',
#   'pay',
#   'price',
#   'disastrous',
#   'decision',
#   'netneutrality',
#   'today'],
#  ['goptaxscam', 'remind', 'longer', 'stink'],
#  ['first',
#   'goptaxscam',
#   'backer',
#   'expect',
#   'working_family',
#   'happy',
#   'crumb',
#   'generous',
#   'cruelty',
#   'know',
#   'bounds'],
#  ['republican',
#   'stuff',
#   'goptaxscam',
#   'permanent',
#   'corporate',
#   'favor',
#   'working',
#   'families’',
#   'expense',
#   'care',
#   'up',
#   'health',
#   'funds',
#   'million'],
#  ['reminder',
#   'party',
#   'fiscal',
#   'responsibility',
#   'would',
#   'burden',
#   'child',
#   'grandchild',
#   'mountain',
#   'finance',
#   'goptaxscam'],
#  ['SCREEN_NAME',
#   'SCREEN_NAME',
#   'enforcement',
#   'announce',
#   'annual',
#   'gunbuyback',
#   'host',
#   'SCREEN_NAME',
#   'responsible',
#   'unwanted',
#   'firearm'],
#  ['SCREEN_NAME',
#   'SCREEN_NAME',
#   'newbritain',
#   'discus',
#   'upcoming',
#   'openenrollment',
#   'deadline',
#   'coverage'],
#  ['mistake',
#   'goptaxscam',
#   'numbers',
#   'congress',
#   'pass',
#   'give',
#   'corporation',
#   'massive',
#   'handout',
#   'back',
#   'people',
#   'SCREEN_NAME'],
#  ['SCREEN_NAME',
#   'republican',
#   'release',
#   'final',
#   '5:30pm',
#   'today',
#   'chance',
#   'fighting',
#   'bitter',
#   'email',
#   'goptaxscam'],
#  ['civilize',
#   'society',
#   'place',
#   'maim',
#   'torturing',
#   'animal',
#   'proud',
#   'partner',
#   'SCREEN_NAME',
#   'pactact',
#   'pass',
#   'senate',
#   'would',
#   'first',
#   'general',
#   'federal',
#   'animal',
#   'cruelty',
#   'statute'],
#  ['still',
#   'massive',
#   'switch',
#   'goptaxscam',
#   'skewer',
#   'middle_class',
#   'enrich',
#   'wealthy',
#   'corporation',
#   'create',
#   'mountain',
#   'child',
#   'fighting'],
#  ['longer',
#   'goptaxscam',
#   'worse',
#   'stink',
#   'wonder',
#   'republican',
#   'rushing',
#   'country',
#   'read'],
#  ['join',
#   'SCREEN_NAME',
#   'newbritain',
#   'kindness',
#   'prepare',
#   'fifth',
#   'anniversary',
#   'sandyhook'],
#  ['optimistic',
#   'ongoing',
#   'bipartisan',
#   'talks',
#   'action',
#   'protect',
#   'dreamer',
#   'unprecedented',
#   'unwise',
#   'deportation',
#   'talented',
#   'hardworking',
#   'young_people',
#   'permanent',
#   'solution',
#   'deserve',
#   'heretostay'],
#  ['republican',
#   'leaders',
#   'congress',
#   'protect',
#   'dreamer',
#   'leaving',
#   'holiday',
#   'reason',
#   'greatest',
#   'country',
#   'world',
#   'nation',
#   'strengthen',
#   'immigrant',
#   'dreamact'],
#  ['sesta',
#   'would',
#   'vindicate',
#   'legal',
#   'right',
#   'victim',
#   'survivor',
#   'traffic',
#   'house',
#   'proposal',
#   'stark',
#   'contrast',
#   'would',
#   'courthouse',
#   'door',
#   'bar',
#   'victim'],
#  ['newbritain',
#   'mariano',
#   'cardoso',
#   'call',
#   'america',
#   'years',
#   'raising',
#   'family',
#   'pay',
#   'tax',
#   'giving',
#   'community',
#   'deport',
#   'permanent',
#   'residency',
#   'application',
#   'remains',
#   'pending',
#   'simply',
#   'shameful'],
#  ['afford',
#   'goptaxscam',
#   'environment',
#   'renewable',
#   'provisions',
#   'joining',
#   'SCREEN_NAME',
#   'urging',
#   'republican',
#   'scrap',
#   'blatant',
#   'baffle',
#   'giveaway',
#   'special',
#   'interest'],
#  ['looking_forward',
#   'joining',
#   'SCREEN_NAME',
#   'expand',
#   'lihtc',
#   'address',
#   'affordablehousing',
#   'crisis',
#   'improve',
#   'health'],
#  ['expect',
#   'incredibly',
#   'transformative',
#   'force',
#   'growth',
#   'productivity',
#   'ready',
#   'future',
#   '---&gt'],
#  ['signing',
#   'defense',
#   'today',
#   'SCREEN_NAME',
#   'strengthening',
#   'military',
#   'approving',
#   'deserve',
#   'raise',
#   'troops',
#   'ensure',
#   'resource',
#   'country',
#   'gapol'],
#  ['people',
#   'connecticut',
#   'disaster',
#   'would',
#   'SCREEN_NAME',
#   'succeed',
#   'rolling',
#   'netneutrality',
#   'could',
#   'agree',
#   'please',
#   'speaking',
#   'standing',
#   'level_playing',
#   'field'],
#  ['SCREEN_NAME',
#   'block',
#   'content',
#   'slow',
#   'speed',
#   'future',
#   'without',
#   'netneutrality',
#   'american',
#   'consumer',
#   'innovator',
#   'SCREEN_NAME',
#   'assault',
#   'internet'],
#  ['retweet',
#   'agree',
#   'SCREEN_NAME',
#   'delay',
#   'thursday',
#   'netneutrality',
#   'pending',
#   'investigation',
#   'possible',
#   'interference',
#   'public',
#   'comment',
#   'process',
#   'future',
#   'internet',
#   'simply',
#   'important'],
#  ['happyhanukkah',
#   'jewish',
#   'community',
#   'across',
#   'colorado',
#   'unite',
#   'state',
#   'everyone',
#   'celebrate',
#   'wonderful',
#   'holiday'],
#  ['happyhanukkah', 'georgian', 'celebrate', 'wonderful', 'holiday'],
#  ['warm',
#   'wish',
#   'friend',
#   'around_world',
#   'celebrate',
#   'first',
#   'night',
#   'hanukkah',
#   'tonight'],
#  ['wishing',
#   'joyful',
#   'bright',
#   'hanukkah_celebrate',
#   'connecticut',
#   'around_world'],
#  ['congratulations',
#   'jones',
#   'decent',
#   'dedicate',
#   'attorney',
#   'stand',
#   'working_family',
#   'senate',
#   'listen',
#   'night'],
#  ['SCREEN_NAME',
#   'whether',
#   'energy',
#   'production',
#   'pipeline',
#   'pump',
#   'storage',
#   'water',
#   'supply',
#   'mining',
#   'permit',
#   'system',
#   'need',
#   'improve',
#   'across',
#   'board',
#   'energy',
#   'SCREEN_NAME'],
#  ['tearing',
#   'netneutrality_rule',
#   'going',
#   'consumer',
#   'internet',
#   'business'],
#  ['today',
#   '1:15et/10:15pt',
#   'joining',
#   'SCREEN_NAME',
#   'affordable',
#   'housing',
#   'lihtc',
#   'improve',
#   'health',
#   'reduce',
#   'health',
#   'costs',
#   'watch'],
#  ['senate_floor',
#   'think',
#   'american_people',
#   'cable',
#   'company',
#   'gatekeeper',
#   'internet',
#   'SCREEN_NAME',
#   'continue',
#   'making',
#   'internet'],
#  ...]

# %%
tag_dictionary = Dictionary(hashtags)
tags_id = [tag_dictionary.doc2idx(tag) for tag in hashtags]

# %%
import torch
from torch import nn
from torch.distributions import constraints

import pyro
import pyro.distributions as dist
from pyro.infer import SVI, JitTraceEnum_ELBO, TraceEnum_ELBO
from pyro.optim import Adam

import functools
from operator import itemgetter

K = 10
V = len(dictionary)
V_per_doc = 5
D = cleaned_tweetz_id.shape[1]
M = len(tag_dictionary)
l_sizes = '500-100-50'

print(f'Number of tags: {M} | Number of Docs: {D}')

# This is a fully generative model of a batch of documents.
# data is a [num_words_per_doc, num_documents] shaped array of word ids
# (specifically it is not a histogram). We assume in this simple example
# that all documents have the same number of words.
def model(data=None, tags=None, batch_size=None):
    # Globals.
    with pyro.plate("topics", K):
        topic_weights = pyro.sample("topic_weights", dist.Gamma(1. / K, 1.))
        topic_words = pyro.sample("topic_words", dist.Dirichlet(torch.ones(V) / V))
        topic_tags_distr = pyro.sample("topic_tags", dist.Dirichlet(torch.ones(M) / M))

    # Locals.
    with pyro.plate("documents", D) as ind:
        if data is not None:
            with pyro.util.ignore_jit_warnings():
                assert data.shape == (V_per_doc, D)
            data = data[:, ind]
            tags = torch.tensor([tags[int(id)][0] for id in ind]).float()

        doc_topics = pyro.sample("doc_topics", dist.Dirichlet(topic_weights))
        with pyro.plate("words", V_per_doc):
            # The word_topics variable is marginalized out during inference,
            # achieved by specifying infer={"enumerate": "parallel"} and using
            # TraceEnum_ELBO for inference. Thus we can ignore this variable in
            # the guide.
            word_topics = pyro.sample("word_topics", dist.Categorical(doc_topics),
                                      infer={"enumerate": "parallel"})
            data = pyro.sample("doc_words", dist.Categorical(topic_words[word_topics]),
                               obs=data)

        # sample 1 topic
        tag_topic = pyro.sample("tag_topic", dist.Categorical(doc_topics), infer={"enumerate": "parallel"})
        if tags is not None:
            tag = pyro.sample("tag", dist.Categorical(topic_tags_distr[tag_topic]), obs=tags)

    return topic_weights, topic_words, data, tag


# We will use amortized inference of the local topic variables, achieved by a
# multi-layer perceptron. We'll wrap the guide in an nn.Module.
def make_predictor():
    layer_sizes = ([V] +
                   [int(s) for s in l_sizes.split('-')] +
                   [K])
    print('Creating MLP with sizes {}'.format(layer_sizes))
    layers = []
    for in_size, out_size in zip(layer_sizes, layer_sizes[1:]):
        layer = nn.Linear(in_size, out_size)
        layer.weight.data.normal_(0, 0.001)
        layer.bias.data.normal_(0, 0.001)
        layers.append(layer)
        layers.append(nn.Sigmoid())
    layers.append(nn.Softmax(dim=-1))
    return nn.Sequential(*layers)


def parametrized_guide(predictor, data, tags, batch_size=None):
    # Use a conjugate guide for global variables.
    topic_weights_posterior = pyro.param("topic_weights_posterior",
        lambda: torch.ones(K),
        constraint=constraints.positive)
    topic_words_posterior = pyro.param("topic_words_posterior",
        lambda: torch.ones(K, V),
        constraint=constraints.greater_than(0.5))
    topic_tags_posterior = pyro.param("topic_tags_posterior",
        lambda: torch.ones(K, M),
        constraint=constraints.greater_than(0.5))
    with pyro.plate("topics", K):
        pyro.sample("topic_weights", dist.Gamma(topic_weights_posterior, 1.))
        pyro.sample("topic_words", dist.Dirichlet(topic_words_posterior))
        pyro.sample("topic_tags", dist.Dirichlet(topic_tags_posterior))

    # Use an amortized guide for local variables.
    pyro.module("predictor", predictor)
    with pyro.plate("documents", D, batch_size) as ind:
        # The neural network will operate on histograms rather than word
        # index vectors, so we'll convert the raw data to a histogram.
        if torch._C._get_tracing_state():
            counts = torch.eye(1024)[data[:, ind]].sum(0).t()
        else:
            counts = torch.zeros(V, ind.size(0))
            counts.scatter_add_(0, data[:, ind], torch.tensor(1.).expand(counts.shape))
        doc_topics = predictor(counts.transpose(0, 1))
        pyro.sample("doc_topics", dist.Delta(doc_topics, event_dim=1))


pyro.set_rng_seed(0)
#pyro.clear_param_store()
# pyro.enable_validation(True)

# We can generate synthetic data directly by calling the model.
#true_topic_weights, true_topic_words, data = model()

# We'll train using SVI.
predictor = make_predictor()
guide = functools.partial(parametrized_guide, predictor)
Elbo = TraceEnum_ELBO  # JitTraceEnum_ELBO if args.jit else TraceEnum_ELBO
elbo = Elbo(max_plate_nesting=2)
optim = Adam({'lr': 1e-2})
svi = SVI(model, guide, optim, elbo)
print('Step\tLoss')
for step in range(5000):
    loss = svi.step(cleaned_tweetz_id, tags_id, batch_size=64)
    if step % 10 == 0:
        print('{: >5d}\t{}'.format(step, loss))
loss = elbo.loss(model, guide, data)
print('final loss = {}'.format(loss))
# Out:
# Number of tags: 725 | Number of Docs: 1899
# Creating MLP with sizes [4227, 500, 100, 50, 10]
# Step	Loss
#     0	407291.25
#    10	411057.75
#    20	397918.375
#    30	397112.875
#    40	398101.46875
#    50	381775.40625
#    60	393088.1875
#    70	387221.0625
#    80	388013.78125
#    90	380743.5625
#   100	388348.90625
#   110	383393.71875
#   120	383877.84375
#   130	378455.625
#   140	398303.75
#   150	379131.28125
#   160	377269.15625
#   170	372439.15625
#   180	372314.9375
#   190	371127.4375
#   200	377577.875
#   210	372556.4375
#   220	369484.375
#   230	367467.8125
#   240	369047.125
#   250	362627.375
#   260	374055.25
#   270	368238.9375
#   280	366829.3125
#   290	365166.8125
#   300	367542.71875
#   310	363581.8125
#   320	368034.9375
#   330	364144.21875
#   340	356425.8125
#   350	354423.25
#   360	358214.21875
#   370	359224.0625
#   380	353577.46875
#   390	357225.0
#   400	354199.03125
#   410	361909.59375
#   420	350048.125
#   430	350637.09375
#   440	349262.5
#   450	349428.6875
#   460	355609.40625
#   470	356165.28125
#   480	346304.65625
#   490	354100.0625
#   500	350260.6875
#   510	361194.25
#   520	357223.53125
#   530	347578.875
#   540	348329.3125
#   550	354728.34375
#   560	347207.53125
#   570	346900.125
#   580	348704.4375
#   590	344664.125
#   600	351435.0625
#   610	344783.6875
#   620	348809.875
#   630	349693.40625
#   640	344166.28125
#   650	345760.0625
#   660	349238.96875
#   670	343551.9375
#   680	352931.125
#   690	344483.0625
#   700	346967.5625
#   710	359355.75
#   720	341133.21875
#   730	343993.5
#   740	342919.28125
#   750	344511.5
#   760	341505.0625
#   770	342351.46875
#   780	346441.3125
#   790	344126.34375
#   800	340725.625
#   810	346716.75
#   820	341103.625
#   830	337720.25
#   840	340908.1875
#   850	350522.15625
#   860	342605.375
#   870	339663.4375
#   880	338272.21875
#   890	340731.09375
#   900	340600.125
#   910	341079.5
#   920	339655.875
#   930	342665.875
#   940	345204.59375
#   950	345488.1875
#   960	342847.46875
#   970	337706.53125
#   980	336381.90625
#   990	343314.4375
#  1000	338165.9375
#  1010	346029.5625
#  1020	341506.03125
#  1030	344619.28125
#  1040	338234.8125
#  1050	334343.8125
#  1060	345300.59375
#  1070	340853.84375
#  1080	338652.90625
#  1090	337762.03125
#  1100	341810.5625
#  1110	341152.78125
#  1120	335238.0625
#  1130	338984.84375
#  1140	340715.53125
#  1150	335131.5
#  1160	338599.25
#  1170	337691.8125
#  1180	330890.5
#  1190	337326.8125
#  1200	338570.75
#  1210	331286.34375
#  1220	336315.3125
#  1230	330222.75
#  1240	344890.125
#  1250	339775.59375
#  1260	339990.75
#  1270	328950.96875
#  1280	336072.40625
#  1290	330620.8125
#  1300	338799.5
#  1310	343801.9375
#  1320	333379.0
#  1330	331681.6875
#  1340	336159.21875
#  1350	333962.34375
#  1360	338893.25
#  1370	329084.34375
#  1380	335835.0625
#  1390	331550.5625
#  1400	332601.375
#  1410	342138.90625
#  1420	330527.75
#  1430	333973.15625
#  1440	331523.0625
#  1450	335887.5625
#  1460	332965.34375
#  1470	347478.28125
#  1480	340989.625
#  1490	333550.6875
#  1500	328992.40625
#  1510	335133.625
#  1520	333260.125
#  1530	327056.625
#  1540	334030.8125
#  1550	333998.125
#  1560	326225.625
#  1570	330269.6875
#  1580	327633.90625
#  1590	333917.75
#  1600	331334.96875
#  1610	335831.0625
#  1620	333386.4375
#  1630	327365.0
#  1640	330925.25
#  1650	329948.59375
#  1660	333724.34375
#  1670	331311.9375
#  1680	327561.28125
#  1690	342502.09375
#  1700	325484.375
#  1710	331556.8125
#  1720	325407.6875
#  1730	326615.65625
#  1740	337768.25
#  1750	326222.0625
#  1760	335027.125
#  1770	331412.34375
#  1780	323332.46875
#  1790	327967.9375
#  1800	326661.8125
#  1810	329962.96875
#  1820	334270.25
#  1830	328775.0
#  1840	330403.3125
#  1850	331288.0625
#  1860	326665.5
#  1870	329305.65625
#  1880	323766.65625
#  1890	324207.875
#  1900	331098.84375
#  1910	331983.9375
#  1920	324954.78125
#  1930	333541.3125
#  1940	324665.09375
#  1950	329787.0625
#  1960	329625.09375
#  1970	325475.5625
#  1980	328335.34375
#  1990	331220.46875
#  2000	332624.03125
#  2010	329451.125
#  2020	337914.34375
#  2030	326423.71875
#  2040	328078.9375
#  2050	323661.34375
#  2060	338464.25
#  2070	328954.71875
#  2080	325630.3125
#  2090	329670.65625
#  2100	323395.84375
#  2110	325193.46875
#  2120	327847.625
#  2130	334755.875
#  2140	325694.28125
#  2150	331024.25
#  2160	337236.0625
#  2170	329599.59375
#  2180	331872.03125
#  2190	323935.78125
#  2200	327689.90625
#  2210	330586.6875
#  2220	325625.0625
#  2230	327501.78125
#  2240	323925.53125
#  2250	323225.5
#  2260	323105.03125
#  2270	322951.0
#  2280	321466.09375
#  2290	328474.90625
#  2300	330133.65625
#  2310	327530.84375
#  2320	324816.125
#  2330	321366.34375
#  2340	319260.71875
#  2350	323663.03125
#  2360	329266.53125
#  2370	328337.6875
#  2380	323948.75
#  2390	323373.59375
#  2400	329965.09375
#  2410	332034.5
#  2420	337119.09375
#  2430	326066.03125
#  2440	321482.9375
#  2450	316881.09375
#  2460	320575.5
#  2470	327678.375
#  2480	334493.125
#  2490	323333.78125
#  2500	324602.53125
#  2510	333120.65625
#  2520	324387.84375
#  2530	322803.28125
#  2540	325383.4375
#  2550	330598.96875
#  2560	327380.0625
#  2570	327623.8125
#  2580	323110.78125
#  2590	319176.75
#  2600	328563.5625
#  2610	337143.625
#  2620	323772.1875
#  2630	324095.46875
#  2640	327322.625
#  2650	324809.5
#  2660	334363.1875
#  2670	320323.9375
#  2680	324782.4375
#  2690	318756.8125
#  2700	324653.71875
#  2710	324580.5625
#  2720	332089.3125
#  2730	321724.125
#  2740	323587.0625
#  2750	320645.625
#  2760	327643.78125
#  2770	319547.125
#  2780	323977.375
#  2790	316991.28125
#  2800	317736.625
#  2810	322064.28125
#  2820	319234.9375
#  2830	318168.0625
#  2840	322046.03125
#  2850	318942.8125
#  2860	318400.46875
#  2870	320225.21875
#  2880	322357.8125
#  2890	327023.875
#  2900	324609.625
#  2910	321750.3125
#  2920	316374.09375
#  2930	320259.59375
#  2940	320385.65625
#  2950	325923.375
#  2960	319471.5625
#  2970	322989.625
#  2980	320443.34375
#  2990	320787.65625
#  3000	328616.53125
#  3010	326557.125
#  3020	326920.125
#  3030	325391.90625
#  3040	319600.4375
#  3050	326739.4375
#  3060	317318.96875
#  3070	324947.15625
#  3080	329486.8125
#  3090	316992.1875
#  3100	318587.5625
#  3110	320362.40625
#  3120	330767.90625
#  3130	320375.78125
#  3140	322882.0625
#  3150	323846.46875
#  3160	319336.03125
#  3170	316205.90625
#  3180	326860.21875
#  3190	320663.53125
#  3200	323020.9375
#  3210	333108.875
#  3220	324463.84375
#  3230	318233.71875
#  3240	322618.9375
#  3250	322435.4375
#  3260	319205.8125
#  3270	317909.9375
#  3280	326388.46875
#  3290	317641.6875
#  3300	314033.53125
#  3310	319231.0
#  3320	322519.40625
#  3330	325269.125
#  3340	325679.75
#  3350	322567.0
#  3360	319568.1875
#  3370	324071.0
#  3380	323130.125
#  3390	320457.3125
#  3400	321324.53125
#  3410	318828.3125
#  3420	322076.75
#  3430	326374.5
#  3440	329411.8125
#  3450	317864.875
#  3460	319811.4375
#  3470	331575.84375
#  3480	320259.4375
#  3490	325021.4375
#  3500	316194.125
#  3510	330756.75
#  3520	316004.25
#  3530	321352.25
#  3540	319399.25
#  3550	332748.375
#  3560	325219.0
#  3570	318481.5
#  3580	314436.15625
#  3590	319088.5
#  3600	321057.875
#  3610	314632.6875
#  3620	316525.0625
#  3630	317109.0625
#  3640	314933.34375
#  3650	320468.71875
#  3660	322850.21875
#  3670	309719.6875
#  3680	320225.03125
#  3690	320196.875
#  3700	314881.625
#  3710	325797.34375
#  3720	315156.34375
#  3730	321816.6875
#  3740	324180.1875
#  3750	323438.0625
#  3760	323413.21875
#  3770	320129.1875
#  3780	327091.90625
#  3790	318947.65625
#  3800	324667.0
#  3810	321273.21875
#  3820	314908.0
#  3830	317898.375
#  3840	313355.6875
#  3850	320617.375
#  3860	321756.78125
#  3870	318957.28125
#  3880	318910.40625
#  3890	313419.78125
#  3900	333387.3125
#  3910	326652.78125
#  3920	313227.28125
#  3930	322680.1875
#  3940	318964.625
#  3950	328103.5
#  3960	315026.59375
#  3970	320675.21875
#  3980	324444.46875
#  3990	323672.59375
#  4000	326697.125
#  4010	318734.46875
#  4020	316208.09375
#  4030	319952.75
#  4040	322333.125
#  4050	324022.34375
#  4060	317734.84375
#  4070	319614.78125
#  4080	321176.40625
#  4090	317366.1875
#  4100	313997.4375
#  4110	313975.3125
#  4120	320768.6875
#  4130	322189.875
#  4140	320197.8125
#  4150	312350.25
#  4160	319496.0625
#  4170	314728.65625
#  4180	313304.4375
#  4190	319334.90625
#  4200	325887.15625
#  4210	320808.5625
#  4220	332296.46875
#  4230	316092.25
#  4240	316982.90625
#  4250	325806.96875
#  4260	314760.1875
#  4270	318088.6875
#  4280	313422.0
#  4290	322537.0625
#  4300	321075.71875
#  4310	325199.5625
#  4320	316268.46875
#  4330	315723.53125
#  4340	314095.90625
#  4350	319641.03125
#  4360	324600.53125
#  4370	312193.53125
#  4380	319010.3125
#  4390	318234.375
#  4400	322752.46875
#  4410	315986.84375
#  4420	318976.1875
#  4430	325497.875
#  4440	321051.8125
#  4450	313635.03125
#  4460	316764.25
#  4470	314138.53125
#  4480	317227.6875
#  4490	321732.125
#  4500	319767.1875
#  4510	311484.15625
#  4520	312617.90625
#  4530	322343.59375
#  4540	319623.78125
#  4550	315740.625
#  4560	317079.4375
#  4570	316941.5
#  4580	323578.0625
#  4590	318920.75
#  4600	316614.28125
#  4610	316377.9375
#  4620	318823.78125
#  4630	313120.15625
#  4640	314366.90625
#  4650	317523.0625
#  4660	314053.25
#  4670	309431.9375
#  4680	311364.5
#  4690	312933.40625
#  4700	312334.09375
#  4710	313517.125
#  4720	312560.71875
#  4730	314659.78125
#  4740	321344.59375
#  4750	317261.46875
#  4760	314020.4375
#  4770	318030.90625
#  4780	322061.9375
#  4790	318437.09375
#  4800	314932.65625
#  4810	311752.40625
#  4820	317687.375
#  4830	311916.125
#  4840	313483.71875
#  4850	317087.375
#  4860	318792.625
#  4870	316089.09375
#  4880	318611.90625
#  4890	315227.90625
#  4900	329111.03125
#  4910	318097.0625
#  4920	322212.28125
#  4930	313433.40625
#  4940	320513.34375
#  4950	316412.5
#  4960	315900.75
#  4970	313272.25
#  4980	321697.15625
#  4990	335196.25
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7a852fdf7821> in <module>
#     129     if step % 10 == 0:
#     130         print('{: >5d}\t{}'.format(step, loss))
# --> 131 loss = elbo.loss(model, guide, data)
#     132 print('final loss = {}'.format(loss))
#
# NameError: name 'data' is not defined

# %%
# Out:
# 'SCREEN_NAME'

# %%
params = pyro.get_param_store()

words_per_topic_distr = params['topic_words_posterior']
tags_in_topic_distr = params['topic_tags_posterior']

topic_words =  dist.Dirichlet(words_per_topic_distr).sample()
tags_topic = dist.Dirichlet(tags_in_topic_distr).sample()

for t in range(K):
    print("---- topic {} -----".format(t))
    print("  -- top words ---")
    top5_words = (torch.argsort(topic_words[t])[-10:]).cpu().numpy()
    top5_words = list(map(lambda x: dictionary[x], reversed(
        top5_words)))
    print(top5_words)
    
    print("  -- top tags ---")
    topk_tags = (torch.argsort(tags_topic[t])[-3:]).cpu().numpy()
    topk_tags = list(map(lambda x: tag_dictionary[x], reversed(topk_tags)))
    print(topk_tags)
# Out:
# ---- topic 0 -----
#   -- top words ---
# ['SCREEN_NAME', 'dreamer', 'family', 'fight', 'another', 'people', 'proud', 'years', 'dreamer_democrat', 'community']
#   -- top tags ---
# ['Dreamers', 'CHIP', 'GOPTaxScam']
# ---- topic 1 -----
#   -- top words ---
# ['visit', 'senator', 'country', 'join', 'business', 'americandreamer', 'alabama', 'icymi', 'morning', 'congrats']
#   -- top tags ---
# ['DreamActNow', 'DREAMers', 'TahoeSummit']
# ---- topic 2 -----
#   -- top words ---
# ['continue', 'joining', 'call', 'honor', 'health_insurance', 'friend', 'opportunity', 'tonight', 'decision', 'discus']
#   -- top tags ---
# ['MonumentsForAll', 'OMDP4NM', 'NAFTA']
# ---- topic 3 -----
#   -- top words ---
# ['great', 'thank', 'netneutrality', 'SCREEN_NAME', '355ships', 'cardinlugar', 'harley', 'older', 'lose', 'teacher']
#   -- top tags ---
# ['GOPTaxScam', 'DRC', 'TheRightSideOfHistory']
# ---- topic 4 -----
#   -- top words ---
# ['senate', 'health', 'solar_eclipse', 'implement', 'SCREEN_NAME', 'judicial_nominee', 'southwest', 'markey', 'development', 'alwaysreadyalwaysthere']
#   -- top tags ---
# ['LastJedi', 'digitaldivide', 'Iran']
# ---- topic 5 -----
#   -- top words ---
# ['SCREEN_NAME', 'republican', 'security', 'steadfast', 'city', '3,000', 'create', 'billy', 'alwaysreadyalwaysthere', 'billings']
#   -- top tags ---
# ['NetNeutrality', 'Dreamers', 'mosen']
# ---- topic 6 -----
#   -- top words ---
# ['SCREEN_NAME', 'large_corporation', 'investigate', 'legislative', 'cable', 'chips', 'propose', 'impressive', 'tenant', 'lowest']
#   -- top tags ---
# ['NetNeutrality', 'CapitoConnect', 'NHCW17']
# ---- topic 7 -----
#   -- top words ---
# ['internet', 'congress', 'american', 'thanks', 'would', 'SCREEN_NAME', 'first', 'taxreform', 'watch', 'child']
#   -- top tags ---
# ['SandyHook', 'ALSEN', 'taxreform']
# ---- topic 8 -----
#   -- top words ---
# ['today', 'goptaxscam', 'support', 'dreamer', 'SCREEN_NAME', 'sonia', 'newark', 'fishing', '.@josephgrenny', 'credit']
#   -- top tags ---
# ['GetCovered', 'MagicCityClassic', 'SoulForcePolitics']
# ---- topic 9 -----
#   -- top words ---
# ['SCREEN_NAME', 'criminal', 'arcticrefuge', 'regulation', 'llws2017', 'outstanding', 'rain', 'inhumane', 'chambers', 'press']
#   -- top tags ---
# ['NetNeutrality', 'opioid', 'FortBragg']

# %%
tags_topic[0].sort()[0][-3:]

# %%
_, _, _, tags = model(cleaned_tweetz_id, tags_id)

# %%
cleaned_tweetz[299]

# %%
for i in range(400, 450):
    print("{} tweet: {} \n| tag: {}\n".format(i, tweets.iloc[i].text, tag_dictionary[int(tags[i])]))
    print('real tags: {}\n\n'.format(tweets.iloc[i].hashtags))
